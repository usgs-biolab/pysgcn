# %% [markdown]
# # Pipeline Stage 5
# The ITIS stage in the SGCN pipeline kicks off all the other stages to operate independently. Since ITIS ends up providing us with a number of additional search vectors and is the primary determinant of putting SGCN species on the National List, we run this stage first to assemble a bunch of additional names to go after from other sources and identifiers to use in at least one case (USFWS Ecological Conservation Online System).
#
# All of the sppin information processors use a single function, process_sppin_source_search_term(), built to handle the only slightly different operations in each case. It can operate against a message queue, retrieving a single message and processing it through to completion. Running the process locally, I first retrieve all messages from a given queue and run them in parallel. The limitations in how many messages we can process come from both the number of concurrent connections we can make to our database and from the number of HTTP requests we want to pass to the ITIS (or any other) API. When moving to a Lambda environment, the database connection issue should no longer be a factor, but we will need to throttle the number of concurrent connections we are sending out to third party APIs.
#
# Note: I did run into a number of interrupts when running the 50K or so unique name/source messages on the ITIS queue in trying to parallel this locally against a SQLite database instance from either database lock issues or ITIS HTTP service connection problems, meaning that it had to be restarted a number of times. This shouldn't be as big a problem in a Lambda environment, but we will need to set up dead letter queue handling if messages fail to process entirely.
#
# The ITIS process proliferates many new messages out onto other queues. It will send all of the names it encounteres, both the original name from the SGCN source and any additional names in the ITIS records (not necessarily all synonyms at this point, just the names encountered through search or following through to valid taxonomic records), to the message queues for other SppIn information gatherers. It will also send any names that it does not find to a WoRMS queue.
#
# Both the ITIS and WoRMS processors also send messages with taxonomic authority summary information when they encounter a usable valid record that are used to infuse additional properties into the SGCN master table indicating whether or not a scientific name should be placed onto the "SGCN National List."

# %%
import pysgcn
sgcn = pysgcn.sgcn.Sgcn()

from joblib import Parallel, delayed
from tqdm import tqdm

mq = "mq_itis_check"
sppin_source = "itis"

# %%
messages = sgcn.sql_mq.get_all_records("mq", mq)

# %%
# %%time
Parallel(n_jobs=7, prefer="threads")(
    delayed(sgcn.process_sppin_source_search_term)
    (
        message_queue=mq,
        sppin_source=sppin_source,
        message_id=message["id"], 
        message_body=message["body"]
    ) for message in tqdm(messages)
)
# Out:
# 100%|██████████| 15084/15084 [06:06<00:00, 41.12it/s]
# CPU times: user 4min 13s, sys: 7min 31s, total: 11min 45s
# Wall time: 6min 36s
# ['MESSAGE PROCESSED: Scientific Name:Sistrurus c. catenatus',
#  'MESSAGE PROCESSED: Scientific Name:Various species of invertebrates',
#  'MESSAGE PROCESSED: Scientific Name:Hemileuca maia ssp',
#  'MESSAGE PROCESSED: Scientific Name:Synedoida adumbrata',
#  'MESSAGE PROCESSED: Scientific Name:Planorbella pilsbryi',
#  'MESSAGE PROCESSED: Scientific Name:Catocala jair ssp',
#  'ALREADY CACHED: Scientific Name:Oeneis jutta',
#  'ALREADY CACHED: Scientific Name:Sphoeroides maculatus',
#  'MESSAGE PROCESSED: Scientific Name:Coregonus reighardi',
#  'ALREADY CACHED: Scientific Name:Hylocichla mustelina',
#  'ALREADY CACHED: Scientific Name:Brevoortia tyrannus',
#  'ALREADY CACHED: Scientific Name:Stylurus spiniceps',
#  'MESSAGE PROCESSED: Scientific Name:Ammocrypta pellucidum',
#  'MESSAGE PROCESSED: Scientific Name:Monoleuca semifascia',
#  'MESSAGE PROCESSED: Scientific Name:Plauditus gloveri',
#  'ALREADY CACHED: Scientific Name:Lycia ypsilon',
#  'ALREADY CACHED: Scientific Name:Hetaerina americana',
#  'ALREADY CACHED: Scientific Name:Apeltes quadricus',
#  'ALREADY CACHED: Scientific Name:Haematopus palliatus',
#  'ALREADY CACHED: Scientific Name:Prosopium cylindraceum',
#  'ALREADY CACHED: Scientific Name:Somatochlora incurvata',
#  'ALREADY CACHED: Scientific Name:Hygrotus sylvanus',
#  'ALREADY CACHED: Scientific Name:Tryngites subruficollis',
#  'ALREADY CACHED: Scientific Name:Xylena thoracica',
#  'ALREADY CACHED: Scientific Name:Aplexa elongata',
#  'MESSAGE PROCESSED: Scientific Name:Torpedo nobiliana',
#  'ALREADY CACHED: Scientific Name:Empidonax traillii',
#  'ALREADY CACHED: Scientific Name:Apamea inordinata',
#  'ALREADY CACHED: Scientific Name:Merolonche dolli',
#  'ALREADY CACHED: TSN:950011',
#  'ALREADY CACHED: Scientific Name:Enallagma minusculum',
#  'ALREADY CACHED: Scientific Name:Dendroica caerulescens',
#  'ALREADY CACHED: Scientific Name:Epioblasma torulosa',
#  'ALREADY CACHED: Scientific Name:Carcharhinus obscurus',
#  'ALREADY CACHED: Scientific Name:Catoptrophorus semipalmatus',
#  'ALREADY CACHED: Scientific Name:Fagitana littera',
#  'ALREADY CACHED: Scientific Name:Pseudopleuronectes americanus',
#  'ALREADY CACHED: Scientific Name:Caprimulgus vociferus',
#  'ALREADY CACHED: Scientific Name:Gavia immer',
#  'ALREADY CACHED: Scientific Name:Cryptotis parva',
#  'ALREADY CACHED: Scientific Name:Dasyatis centroura',
#  'ALREADY CACHED: Scientific Name:Notropis heterodon',
#  'ALREADY CACHED: Scientific Name:Aquila chrysaetos',
#  'ALREADY CACHED: Scientific Name:Egretta thula',
#  'ALREADY CACHED: Scientific Name:Hypomecis buchholzaria',
#  'ALREADY CACHED: Scientific Name:Terrapene carolina',
#  'ALREADY CACHED: Scientific Name:Acris crepitans',
#  'ALREADY CACHED: Scientific Name:Utterbackia imbecillis',
#  'ALREADY CACHED: Scientific Name:Accipiter striatus',
#  'ALREADY CACHED: Scientific Name:Dendroica discolor',
#  'ALREADY CACHED: Scientific Name:Sterna caspia',
#  'ALREADY CACHED: Scientific Name:Etheostoma fusiforme',
#  'ALREADY CACHED: Scientific Name:Quadrula quadrula',
#  'ALREADY CACHED: Scientific Name:Papaipema cerina',
#  'ALREADY CACHED: Scientific Name:Sphyrna tiburo',
#  'ALREADY CACHED: Scientific Name:Cordulegaster erronea',
#  'ALREADY CACHED: Scientific Name:Stagnicola woodruffi',
#  'ALREADY CACHED: Scientific Name:Dendroica cerulea',
#  'ALREADY CACHED: Scientific Name:Dendroica castanea',
#  'ALREADY CACHED: Scientific Name:Coccyzus erythropthalmus',
#  'ALREADY CACHED: Scientific Name:Numenius phaeopus',
#  'ALREADY CACHED: Scientific Name:Simpsonaias ambigua',
#  'MESSAGE PROCESSED: Scientific Name:Procloeon vicinum',
#  'ALREADY CACHED: Scientific Name:Argopecten irradians',
#  'ALREADY CACHED: Scientific Name:Polyodon spathula',
#  'ALREADY CACHED: Scientific Name:Alosa sapidissima',
#  'ALREADY CACHED: Scientific Name:Sterna dougallii',
#  'ALREADY CACHED: Scientific Name:Falco peregrinus',
#  'ALREADY CACHED: Scientific Name:Isurus paucus',
#  'ALREADY CACHED: Scientific Name:Trichoclea artesta',
#  'ALREADY CACHED: Scientific Name:Melanitta nigra',
#  'ALREADY CACHED: Scientific Name:Graptemys geographica',
#  'ALREADY CACHED: Scientific Name:Ammodramus caudacutus',
#  'ALREADY CACHED: Scientific Name:Malacoraja senta',
#  'ALREADY CACHED: Scientific Name:Ligumia recta',
#  'MESSAGE PROCESSED: Scientific Name:Morrisonia mucens',
#  'ALREADY CACHED: Scientific Name:Neotoma magister',
#  'MESSAGE PROCESSED: Scientific Name:Euxoa lidia thanatologia',
#  'ALREADY CACHED: Scientific Name:Cicindela puritana',
#  'ALREADY CACHED: Scientific Name:Acantharchus pomotis',
#  'ALREADY CACHED: Scientific Name:Necturus maculosus',
#  'ALREADY CACHED: Scientific Name:Ligumia nasuta',
#  'ALREADY CACHED: Scientific Name:Salmo salar',
#  'ALREADY CACHED: Scientific Name:Callinectes sapidus',
#  'ALREADY CACHED: Scientific Name:Lontra canadensis',
#  'ALREADY CACHED: Scientific Name:Moxostoma duquesnei',
#  'ALREADY CACHED: Scientific Name:Carphophis amoenus',
#  'ALREADY CACHED: Scientific Name:Pleurobema clava',
#  'ALREADY CACHED: Scientific Name:Valvata sincera',
#  'ALREADY CACHED: Scientific Name:Bubulcus ibis',
#  'ALREADY CACHED: Scientific Name:Aythya affinis',
#  'ALREADY CACHED: Scientific Name:Coregonus hoyi',
#  'ALREADY CACHED: Scientific Name:Spiza americana',
#  'ALREADY CACHED: Scientific Name:Truncilla truncata',
#  'ALREADY CACHED: Scientific Name:Abagrotis nefascia benjamini',
#  'MESSAGE PROCESSED: Scientific Name:Calpodes ethlius',
#  'ALREADY CACHED: Scientific Name:Papaipema marginidens',
#  'ALREADY CACHED: Scientific Name:Wilsonia canadensis',
#  'ALREADY CACHED: Scientific Name:Erimyzon sucetta',
#  'ALREADY CACHED: Scientific Name:Somatochlora minor',
#  'ALREADY CACHED: Scientific Name:Histrionicus histrionicus',
#  'ALREADY CACHED: Scientific Name:Siphlonisca aerodromia',
#  'ALREADY CACHED: Scientific Name:Eumeces anthracinus',
#  'ALREADY CACHED: Scientific Name:Calidris alpina',
#  'ALREADY CACHED: Scientific Name:Carcharodon carcharias',
#  'ALREADY CACHED: Scientific Name:Callophrys lanoraieensis',
#  'ALREADY CACHED: Scientific Name:Enallagma laterale',
#  'ALREADY CACHED: Scientific Name:Martes americana',
#  'ALREADY CACHED: Scientific Name:Sideridis maryx',
#  'ALREADY CACHED: Scientific Name:Erynnis persius persius',
#  'ALREADY CACHED: Scientific Name:Ambystoma jeffersonianum',
#  'ALREADY CACHED: Scientific Name:Epeorus punctatus',
#  'ALREADY CACHED: Scientific Name:Orgyia detrita',
#  'MESSAGE PROCESSED: Scientific Name:Semiothisa banksianae',
#  'ALREADY CACHED: Scientific Name:Plegadis falcinellus',
#  'MESSAGE PROCESSED: Scientific Name:Paectes abrostolella',
#  'ALREADY CACHED: Scientific Name:Eretmochelys imbricata',
#  'ALREADY CACHED: Scientific Name:Fundulus luciae',
#  'ALREADY CACHED: Scientific Name:Lanius ludovicianus',
#  'MESSAGE PROCESSED: Scientific Name:Papaipema harrisii',
#  'ALREADY CACHED: Scientific Name:Percina macrocephala',
#  'MESSAGE PROCESSED: Scientific Name:Schinia tuberculum',
#  'ALREADY CACHED: Scientific Name:Rhithrogena anomala',
#  'ALREADY CACHED: Scientific Name:Melanitta perspicillata',
#  'ALREADY CACHED: Scientific Name:Parasa indetermina',
#  'ALREADY CACHED: Scientific Name:Etheostoma camurum',
#  'ALREADY CACHED: Scientific Name:Stylurus plagiatus',
#  'ALREADY CACHED: Scientific Name:Anodonta implicata',
#  'ALREADY CACHED: Scientific Name:Epioblasma triquetra',
#  'ALREADY CACHED: Scientific Name:Limosa haemastica',
#  'ALREADY CACHED: Scientific Name:Erynnis martialis',
#  'MESSAGE PROCESSED: Scientific Name:Agrotis obliqua',
#  'ALREADY CACHED: Scientific Name:Megaptera novaeangliae',
#  'MESSAGE PROCESSED: Scientific Name:Larus philadelphia',
#  'ALREADY CACHED: Scientific Name:Melanitta fusca',
#  'MESSAGE PROCESSED: Scientific Name:Manta birostris',
#  'ALREADY CACHED: Scientific Name:Alopias vulpinus',
#  'ALREADY CACHED: Scientific Name:Aythya marila',
#  'ALREADY CACHED: Scientific Name:Cambarus diogenes',
#  'ALREADY CACHED: Scientific Name:Oxyura jamaicensis',
#  'ALREADY CACHED: Scientific Name:Podiceps auritus',
#  'ALREADY CACHED: Scientific Name:Hydraecia stramentosa',
#  'ALREADY CACHED: Scientific Name:Euxoa pleuritica',
#  'ALREADY CACHED: Scientific Name:Sphyrna lewini',
#  'ALREADY CACHED: Scientific Name:Lithophane lemmeri',
#  'ALREADY CACHED: Scientific Name:Prionace glauca',
#  'ALREADY CACHED: Scientific Name:Oporornis formosus',
#  'ALREADY CACHED: Scientific Name:Puffinus gravis',
#  'ALREADY CACHED: Scientific Name:Anchoa mitchilli',
#  'MESSAGE PROCESSED: Scientific Name:Rhithrogena uhari',
#  'ALREADY CACHED: Scientific Name:Speyeria idalia',
#  'ALREADY CACHED: Scientific Name:Microgadus tomcod',
#  'ALREADY CACHED: Scientific Name:Dolichonyx oryzivorus',
#  'MESSAGE PROCESSED: Scientific Name:Metalectra tantillus',
#  'MESSAGE PROCESSED: Scientific Name:Abagrotis barnesi',
#  'ALREADY CACHED: Scientific Name:Sternotherus odoratus',
#  'ALREADY CACHED: Scientific Name:Cerma cora',
#  'ALREADY CACHED: Scientific Name:Cicinnus melsheimeri',
#  'ALREADY CACHED: Scientific Name:Calonectris diomedea',
#  'ALREADY CACHED: Scientific Name:Catocala badia',
#  'ALREADY CACHED: Scientific Name:Obovaria olivaria',
#  'ALREADY CACHED: Scientific Name:Zanclognatha martha',
#  'ALREADY CACHED: Scientific Name:Fundulus majalis',
#  'ALREADY CACHED: Scientific Name:Myoxocephalus thompsoni',
#  'ALREADY CACHED: Scientific Name:Clemmys muhlenbergii',
#  'ALREADY CACHED: Scientific Name:Potamilus capax',
#  'ALREADY CACHED: Scientific Name:Cincinnatia cincinnatiensis',
#  'ALREADY CACHED: Scientific Name:Citheronia sepulcralis',
#  'ALREADY CACHED: Scientific Name:Ophiogomphus aspersus',
#  'ALREADY CACHED: Scientific Name:Uca pugnax',
#  'ALREADY CACHED: Scientific Name:Nicrophorus americanus',
#  'ALREADY CACHED: Scientific Name:Valvata perdepressa',
#  'ALREADY CACHED: Scientific Name:Bonasa umbellus',
#  'MESSAGE PROCESSED: Scientific Name:Baetis rusticans',
#  'ALREADY CACHED: Scientific Name:Amblyraja radiata',
#  'ALREADY CACHED: Scientific Name:Chlidonias niger',
#  'ALREADY CACHED: Scientific Name:Epeorus frisoni',
#  'ALREADY CACHED: Scientific Name:Lampsilis ovata',
#  'MESSAGE PROCESSED: Scientific Name:Semiothisa denticulata',
#  'ALREADY CACHED: Scientific Name:Calephelis borealis',
#  'ALREADY CACHED: Scientific Name:Catocala pretiosa pretiosa',
#  'ALREADY CACHED: Scientific Name:Williamsonia lintneri',
#  'ALREADY CACHED: Scientific Name:Calidris maritima',
#  'ALREADY CACHED: Scientific Name:Phyciodes batesii batesii',
#  'ALREADY CACHED: Scientific Name:Rallus elegans',
#  'MESSAGE PROCESSED: Scientific Name:Felis concolor cougar',
#  'ALREADY CACHED: Scientific Name:Canis lupus',
#  'ALREADY CACHED: Scientific Name:Laterallus jamaicensis',
#  'ALREADY CACHED: Scientific Name:Toxostoma rufum',
#  'ALREADY CACHED: Scientific Name:Erimystax x-punctatus',
#  'ALREADY CACHED: Scientific Name:Vermivora chrysoptera',
#  'ALREADY CACHED: Scientific Name:Tautoga onitis',
#  'ALREADY CACHED: Scientific Name:Hybopsis amblops',
#  'ALREADY CACHED: Scientific Name:Asio flammeus',
#  'ALREADY CACHED: Scientific Name:Larus atricilla',
#  'ALREADY CACHED: Scientific Name:Dendroica tigrina',
#  'ALREADY CACHED: Scientific Name:Caretta caretta',
#  'ALREADY CACHED: Scientific Name:Callophrys henrici',
#  'ALREADY CACHED: Scientific Name:Asio otus',
#  'MESSAGE PROCESSED: Scientific Name:Larus thayeri',
#  'ALREADY CACHED: Scientific Name:Tyto alba',
#  'ALREADY CACHED: Scientific Name:Bucephala clangula',
#  'ALREADY CACHED: Scientific Name:Somatochlora forcipata',
#  'ALREADY CACHED: Scientific Name:Euphagus carolinus',
#  'ALREADY CACHED: Scientific Name:Bufo fowleri',
#  'ALREADY CACHED: Scientific Name:Anas discors',
#  'ALREADY CACHED: Scientific Name:Limosa fedoa',
#  'ALREADY CACHED: Scientific Name:Eumeces fasciatus',
#  'ALREADY CACHED: Scientific Name:Agkistrodon contortrix mokasen',
#  'ALREADY CACHED: Scientific Name:Scolopax minor',
#  'ALREADY CACHED: Scientific Name:Lasiurus borealis',
#  'ALREADY CACHED: Scientific Name:Gomphus viridifrons',
#  'ALREADY CACHED: Scientific Name:Myotis leibii',
#  'ALREADY CACHED: Scientific Name:Phoberia orthosioides',
#  'ALREADY CACHED: Scientific Name:Leptodea ochracea',
#  'ALREADY CACHED: Scientific Name:Papaipema duovata',
#  'ALREADY CACHED: Scientific Name:Calopteryx dimidiata',
#  'MESSAGE PROCESSED: Scientific Name:Physella vinosa',
#  'ALREADY CACHED: Scientific Name:Stylurus notatus',
#  'ALREADY CACHED: Scientific Name:Fontigens nickliniana',
#  'MESSAGE PROCESSED: Scientific Name:Chytonix ruperti',
#  'ALREADY CACHED: Scientific Name:Alosa pseudoharengus',
#  'ALREADY CACHED: Scientific Name:Cicindela marginipennis',
#  'ALREADY CACHED: Scientific Name:Thamnophis sauritus sauritus',
#  'ALREADY CACHED: Scientific Name:Opheodrys vernalis',
#  'ALREADY CACHED: Scientific Name:Obovaria subrotunda',
#  'ALREADY CACHED: Scientific Name:Menidia menidia',
#  'ALREADY CACHED: Scientific Name:Aeshna subarctica',
#  'ALREADY CACHED: Scientific Name:Ammodramus henslowii',
#  'ALREADY CACHED: Scientific Name:Ichthyomyzon bdellium',
#  'ALREADY CACHED: Scientific Name:Pleurobema sintoxia',
#  'ALREADY CACHED: Scientific Name:Alosa aestivalis',
#  'ALREADY CACHED: Scientific Name:Lasmigona complanata',
#  'ALREADY CACHED: Scientific Name:Charadrius melodus',
#  'ALREADY CACHED: Scientific Name:Hemidactylium scutatum',
#  'ALREADY CACHED: Scientific Name:Chaetaglaea cerata',
#  'ALREADY CACHED: Scientific Name:Catocala herodias gerhardi',
#  'ALREADY CACHED: Scientific Name:Coregonus kiyi',
#  'ALREADY CACHED: Scientific Name:Gomphus abbreviatus',
#  'ALREADY CACHED: Scientific Name:Nehalennia integricollis',
#  'ALREADY CACHED: Scientific Name:Tachopteryx thoreyi',
#  'ALREADY CACHED: Scientific Name:Epioblasma torulosa rangiana',
#  'ALREADY CACHED: Scientific Name:Hippocampus erectus',
#  'ALREADY CACHED: Scientific Name:Argia tibialis',
#  'ALREADY CACHED: Scientific Name:Euchloe olympia',
#  'MESSAGE PROCESSED: Scientific Name:Trionyx spiniferus',
#  'ALREADY CACHED: Scientific Name:Pyrgus wyandot',
#  'ALREADY CACHED: Scientific Name:Tringa melanoleuca',
#  'ALREADY CACHED: Scientific Name:Macrhybopsis storeriana',
#  'ALREADY CACHED: Scientific Name:Cistothorus platensis',
#  'ALREADY CACHED: Scientific Name:Regina septemvittata',
#  'ALREADY CACHED: Scientific Name:Eacles imperialis pini',
#  'ALREADY CACHED: Scientific Name:Richia acclivis',
#  'ALREADY CACHED: Scientific Name:Chytonix sensilis',
#  'ALREADY CACHED: Scientific Name:Myotis sodalis',
#  'MESSAGE PROCESSED: Scientific Name:Heptagenia julia',
#  'ALREADY CACHED: Scientific Name:Homarus americanus',
#  'ALREADY CACHED: Scientific Name:Notropis amoenus',
#  'ALREADY CACHED: Scientific Name:Clangula hyemalis',
#  'ALREADY CACHED: Scientific Name:Anax longipes',
#  'ALREADY CACHED: Scientific Name:Artace cribraria',
#  'ALREADY CACHED: Scientific Name:Euchlaena madusaria',
#  'ALREADY CACHED: Scientific Name:Lithophane lepida lepida',
#  'ALREADY CACHED: Scientific Name:Villosa fabalis',
#  'ALREADY CACHED: Scientific Name:Etheostoma maculatum',
#  'MESSAGE PROCESSED: Scientific Name:Brachycercus maculatus',
#  'ALREADY CACHED: Scientific Name:Fixsenia favonius ontario',
#  'MESSAGE PROCESSED: Scientific Name:Thioptera nigrofimbria',
#  'MESSAGE PROCESSED: Scientific Name:Procloeon ozburni',
#  'ALREADY CACHED: Scientific Name:Sterna hirundo',
#  'ALREADY CACHED: Scientific Name:Chordeiles minor',
#  'MESSAGE PROCESSED: Scientific Name:Procloeon simile',
#  'ALREADY CACHED: Scientific Name:Metarranthis apiciaria',
#  'ALREADY CACHED: Scientific Name:Callophrys hesseli',
#  'ALREADY CACHED: Scientific Name:Galeocerdo cuvier',
#  'ALREADY CACHED: Scientific Name:Kinosternon subrubrum',
#  'ALREADY CACHED: Scientific Name:Pooecetes gramineus',
#  'ALREADY CACHED: Scientific Name:Callophrys irus',
#  'ALREADY CACHED: Scientific Name:Tautogolabrus adspersus',
#  'ALREADY CACHED: Scientific Name:Lasiurus cinereus',
#  'ALREADY CACHED: Scientific Name:Libellula needhami',
#  'ALREADY CACHED: Scientific Name:Pseudacris triseriata',
#  'ALREADY CACHED: Scientific Name:Birgella subglobosus',
#  'ALREADY CACHED: Scientific Name:Accipiter cooperii',
#  'ALREADY CACHED: Scientific Name:Cottus ricei',
#  'ALREADY CACHED: Scientific Name:Alasmidonta marginata',
#  'ALREADY CACHED: Scientific Name:Acipenser fulvescens',
#  'ALREADY CACHED: Scientific Name:Progomphus obscurus',
#  'ALREADY CACHED: Scientific Name:Rhinoptera bonasus',
#  'ALREADY CACHED: Scientific Name:Clemmys guttata',
#  'ALREADY CACHED: Scientific Name:Procloeon mendax',
#  'ALREADY CACHED: Scientific Name:Ammodramus savannarum',
#  'ALREADY CACHED: Scientific Name:Coturnicops noveboracensis',
#  'MESSAGE PROCESSED: Scientific Name:Tornos scolopacinarius',
#  'ALREADY CACHED: Scientific Name:Sterna antillarum',
#  'ALREADY CACHED: Scientific Name:Sympetrum danae',
#  'ALREADY CACHED: Scientific Name:Etheostoma exile',
#  'ALREADY CACHED: Scientific Name:Villosa iris',
#  'ALREADY CACHED: Scientific Name:Balaenoptera musculus',
#  'ALREADY CACHED: Scientific Name:Osmerus mordax',
#  'ALREADY CACHED: Scientific Name:Acella haldemani',
#  'ALREADY CACHED: Scientific Name:Lampsilis fasciola',
#  'ALREADY CACHED: Scientific Name:Cicindela ancocisconensis',
#  'ALREADY CACHED: Scientific Name:Aeshna mutata',
#  'ALREADY CACHED: Scientific Name:Heptagenia culacantha',
#  'ALREADY CACHED: Scientific Name:Alasmidonta varicosa',
#  'ALREADY CACHED: Scientific Name:Cetorhinus maximus',
#  'ALREADY CACHED: Scientific Name:Egretta tricolor',
#  'ALREADY CACHED: Scientific Name:Ixobrychus exilis',
#  'MESSAGE PROCESSED: Scientific Name:Sericaglaea signata',
#  'MESSAGE PROCESSED: Scientific Name:Anomogyna rhaetica',
#  'ALREADY CACHED: Scientific Name:Cicindela dorsalis dorsalis',
#  'ALREADY CACHED: Scientific Name:Stylurus amnicola',
#  'ALREADY CACHED: Scientific Name:Somatochlora cingulata',
#  'ALREADY CACHED: Scientific Name:Gasterosteus aculeatus',
#  'MESSAGE PROCESSED: Scientific Name:Psaphida thaxteriana',
#  'MESSAGE PROCESSED: Scientific Name:Schinia bifascia',
#  'ALREADY CACHED: Scientific Name:Seiurus motacilla',
#  'ALREADY CACHED: Scientific Name:Stygobromus tenuis tenuis',
#  'ALREADY CACHED: Scientific Name:Acipenser brevirostrum',
#  'ALREADY CACHED: Scientific Name:Eremophila alpestris',
#  'ALREADY CACHED: Scientific Name:Calidris canutus',
#  'ALREADY CACHED: Scientific Name:Ischnura ramburii',
#  'ALREADY CACHED: Scientific Name:Actinonaias ligamentina',
#  'ALREADY CACHED: Scientific Name:Lampsilis teres',
#  'MESSAGE PROCESSED: Scientific Name:Hairy artesta',
#  'ALREADY CACHED: Scientific Name:Dermochelys coriacea',
#  'ALREADY CACHED: Scientific Name:Glaucopsyche lygdamus lygdamus',
#  'ALREADY CACHED: Scientific Name:Circus cyaneus',
#  'ALREADY CACHED: Scientific Name:Ambystoma tigrinum',
#  'ALREADY CACHED: Scientific Name:Icteria virens',
#  'ALREADY CACHED: Scientific Name:Raja eglanteria',
#  'ALREADY CACHED: Scientific Name:Anas acuta',
#  'ALREADY CACHED: Scientific Name:Itame',
#  'ALREADY CACHED: Scientific Name:Eucoptocnemis fimbriaris',
#  'ALREADY CACHED: Scientific Name:Sceloporus undulatus',
#  'ALREADY CACHED: Scientific Name:Siphlonurus barbaroides',
#  'ALREADY CACHED: Scientific Name:Lithophane viridipallens',
#  'ALREADY CACHED: Scientific Name:Picoides tridactylus',
#  'ALREADY CACHED: Scientific Name:Pteronarcys comstocki',
#  'ALREADY CACHED: Scientific Name:Orthodes obscura',
#  'ALREADY CACHED: Scientific Name:Ophiogomphus colubrinus',
#  'ALREADY CACHED: Scientific Name:Gomphus ventricosus',
#  'ALREADY CACHED: Scientific Name:Botaurus lentiginosus',
#  'ALREADY CACHED: Scientific Name:Catocala',
#  'MESSAGE PROCESSED: Scientific Name:Amphipoea erepta ryensis',
#  'ALREADY CACHED: Scientific Name:Somatochlora linearis',
#  'ALREADY CACHED: Scientific Name:Alloperla voinae',
#  'ALREADY CACHED: Scientific Name:Lamna nasus',
#  'ALREADY CACHED: Scientific Name:Gillia altilis',
#  'ALREADY CACHED: Scientific Name:Moxostoma carinatum',
#  'ALREADY CACHED: Scientific Name:Datana ranaeceps',
#  'ALREADY CACHED: Scientific Name:Haliaeetus leucocephalus',
#  'ALREADY CACHED: Scientific Name:Sterna nilotica',
#  'ALREADY CACHED: Scientific Name:Ardea alba',
#  'ALREADY CACHED: Scientific Name:Cicindela abdominalis',
#  'MESSAGE PROCESSED: Scientific Name:Paralithodes platypus',
#  'ALREADY CACHED: Scientific Name:Calidris virgata',
#  'ALREADY CACHED: Scientific Name:Calidris mauri',
#  'MESSAGE PROCESSED: Scientific Name:Patinopecten caurinus',
#  'ALREADY CACHED: Scientific Name:Boreogadus saida',
#  'ALREADY CACHED: Scientific Name:Sorex monticolus malitiosus',
#  'ALREADY CACHED: Scientific Name:Coregonus pidschian',
#  'ALREADY CACHED: Scientific Name:Melanitta americana',
#  'ALREADY CACHED: Scientific Name:Ambystoma macrodactylum',
#  'MESSAGE PROCESSED: Scientific Name:Dicrostonyx nelson',
#  'ALREADY CACHED: Scientific Name:Calidris canutus roselaari',
#  'ALREADY CACHED: Scientific Name:Enhydra lutris kenyoni',
#  'ALREADY CACHED: Scientific Name:Setophaga petechia',
#  'ALREADY CACHED: Scientific Name:Calidris ptilocnemis couesi',
#  'ALREADY CACHED: Scientific Name:Surnia ulula',
#  'ALREADY CACHED: Scientific Name:Hypomesus pretiosus',
#  'ALREADY CACHED: Scientific Name:Sorex pribilofensis',
#  'ALREADY CACHED: Scientific Name:Calidris alba',
#  'ALREADY CACHED: Scientific Name:Sorex jacksoni',
#  'ALREADY CACHED: Scientific Name:Cyanocitta stelleri',
#  'MESSAGE PROCESSED: Scientific Name:Accipiter gentilis laingi',
#  'ALREADY CACHED: Scientific Name:Sebastes auriculatus',
#  'ALREADY CACHED: Scientific Name:Phoebastria nigripes',
#  'MESSAGE PROCESSED: Scientific Name:Troglodytes pacificus alascensis',
#  'ALREADY CACHED: Scientific Name:Luscinia svecica',
#  'MESSAGE PROCESSED: Scientific Name:Melospiza melodia caurina',
#  'ALREADY CACHED: Scientific Name:Balaenoptera physalus',
#  'ALREADY CACHED: Scientific Name:Polysticta stelleri',
#  'ALREADY CACHED: Scientific Name:Empidonax alnorum',
#  'MESSAGE PROCESSED: Scientific Name:Macoma balthica',
#  'ALREADY CACHED: Scientific Name:Physeter macrocephalus',
#  'ALREADY CACHED: Scientific Name:Bartramia longicauda',
#  'MESSAGE PROCESSED: Scientific Name:Panopea generosa',
#  'ALREADY CACHED: Scientific Name:Cypseloides niger borealis',
#  'ALREADY CACHED: Scientific Name:Delphinapterus leucas',
#  'MESSAGE PROCESSED: Scientific Name:Strix nebulosi',
#  'ALREADY CACHED: Scientific Name:Phylloscopus borealis',
#  'MESSAGE PROCESSED: Scientific Name:Lamna ditropis',
#  'MESSAGE PROCESSED: Scientific Name:Berrytheuthis magister',
#  'MESSAGE PROCESSED: Scientific Name:Calcarius lapponicus alascensis',
#  'ALREADY CACHED: Scientific Name:Trichoptera',
#  'ALREADY CACHED: Scientific Name:Sebastes maliger',
#  'ALREADY CACHED: Scientific Name:Eumetopias jubatus',
#  'ALREADY CACHED: Scientific Name:Gavia adamsii',
#  'ALREADY CACHED: Scientific Name:Aethia cristatella',
#  'MESSAGE PROCESSED: Scientific Name:Setophaga petechial banksi',
#  'MESSAGE PROCESSED: Scientific Name:Eleginus gracilis',
#  'ALREADY CACHED: Scientific Name:Balaenoptera borealis',
#  'ALREADY CACHED: Scientific Name:Falco rusticolus',
#  'ALREADY CACHED: Scientific Name:Regulus satrapa',
#  'MESSAGE PROCESSED: Scientific Name:Passerella iliaca sinuosa',
#  'ALREADY CACHED: Scientific Name:Sebastes paucispinis',
#  'MESSAGE PROCESSED: Scientific Name:Picoides villosus sitkensis',
#  'ALREADY CACHED: Scientific Name:Phocoena phocoena',
#  'MESSAGE PROCESSED: Scientific Name:Buteo jamaicensis harlani',
#  'MESSAGE PROCESSED: Scientific Name:Somateria spectablis',
#  'ALREADY CACHED: Scientific Name:Anaxyrus boreas',
#  'MESSAGE PROCESSED: Scientific Name:Eremophila alpestris arcticola',
#  'ALREADY CACHED: Scientific Name:Branta canadensis occidentalis',
#  'ALREADY CACHED: Scientific Name:Plecoptera',
#  'MESSAGE PROCESSED: Scientific Name:Melospiza melodia rufina',
#  'MESSAGE PROCESSED: Scientific Name:Setophaga townsendi',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus tshawytscha',
#  'MESSAGE PROCESSED: Scientific Name:Sorex monticolus longicaudus',
#  'MESSAGE PROCESSED: Scientific Name:Sorex monticolus shumaginensis',
#  'MESSAGE PROCESSED: Scientific Name:Troglodytes pacificus kiskensis',
#  'MESSAGE PROCESSED: Scientific Name:Corvus corax kamtschaticus',
#  'MESSAGE PROCESSED: Scientific Name:Urocitellus parryii kodiacensis',
#  'MESSAGE PROCESSED: Scientific Name:Vulpes lagopus',
#  'ALREADY CACHED: Scientific Name:Megascops kennicottii',
#  'ALREADY CACHED: Scientific Name:Phoebastria immutabilis',
#  'MESSAGE PROCESSED: Scientific Name:Euphasiacea',
#  'ALREADY CACHED: Scientific Name:Dallia pectoralis',
#  'MESSAGE PROCESSED: Scientific Name:Picoides pubescens glacialis',
#  'ALREADY CACHED: Scientific Name:Calidris pusilla',
#  'ALREADY CACHED: Scientific Name:Glaucomys sabrinus',
#  'ALREADY CACHED: Scientific Name:Myotis volans',
#  'ALREADY CACHED: Scientific Name:Haliotis kamtschatkana',
#  'ALREADY CACHED: Scientific Name:Percopsis omiscomaycus',
#  'ALREADY CACHED: Scientific Name:Somateria mollissima',
#  'MESSAGE PROCESSED: Scientific Name:Onychoprion aleuticus',
#  'ALREADY CACHED: Scientific Name:Phalacrocorax pelagicus',
#  'ALREADY CACHED: Scientific Name:Thymallus arcticus',
#  'MESSAGE PROCESSED: Scientific Name:Sebastes variabilis',
#  'ALREADY CACHED: Scientific Name:Poecile atricapillus',
#  'MESSAGE PROCESSED: Scientific Name:Melospiza melodia kenaiensis',
#  'MESSAGE PROCESSED: Scientific Name:Pandalus goniurus',
#  'MESSAGE PROCESSED: Scientific Name:Larus glaucescens',
#  'MESSAGE PROCESSED: Scientific Name:Uria lomvia arra',
#  'ALREADY CACHED: Scientific Name:Pluvialis dominica',
#  'ALREADY CACHED: Scientific Name:Zonotrichia atricapilla',
#  'MESSAGE PROCESSED: Scientific Name:Cepphus grille',
#  'ALREADY CACHED: Scientific Name:Salvelinus namaycush',
#  'ALREADY CACHED: Scientific Name:Gavia stellata',
#  'MESSAGE PROCESSED: Scientific Name:Salvelinus alpinus',
#  'ALREADY CACHED: Scientific Name:Aethia pusilla',
#  'MESSAGE PROCESSED: Scientific Name:Phoca vitulina richardii',
#  'ALREADY CACHED: Scientific Name:Ephemeroptera',
#  'MESSAGE PROCESSED: Scientific Name:Microgadus proximus',
#  'MESSAGE PROCESSED: Scientific Name:Pleurogrammus monopterygius',
#  'ALREADY CACHED: Scientific Name:Marmota broweri',
#  'ALREADY CACHED: Scientific Name:Zonotrichia leucophrys',
#  'ALREADY CACHED: Scientific Name:Contopus sordidulus',
#  'ALREADY CACHED: Scientific Name:Microtus abbreviatus',
#  'ALREADY CACHED: Scientific Name:Gavia arctica',
#  'ALREADY CACHED: Scientific Name:Phoca largha',
#  'ALREADY CACHED: Scientific Name:Sebastes melanops',
#  'ALREADY CACHED: Scientific Name:Limnodromus griseus caurinus',
#  'MESSAGE PROCESSED: Scientific Name:Katharina tunicate',
#  'ALREADY CACHED: Scientific Name:Hymenoptera',
#  'MESSAGE PROCESSED: Scientific Name:Histriophoca fasciata',
#  'ALREADY CACHED: Scientific Name:Coregonus nasus',
#  'ALREADY CACHED: Scientific Name:Charadrius vociferous',
#  'ALREADY CACHED: Scientific Name:Thaleichthys pacificus',
#  'MESSAGE PROCESSED: Scientific Name:Plectrophenax nivalis townsendi',
#  'ALREADY CACHED: Scientific Name:Eubalaena japonica',
#  'MESSAGE PROCESSED: Scientific Name:Setophaga petechial rubiginosa',
#  'ALREADY CACHED: Scientific Name:Synaptomys borealis',
#  'MESSAGE PROCESSED: Scientific Name:Stercarius longicaudus',
#  'MESSAGE PROCESSED: Scientific Name:Troglodytes pacificus',
#  'ALREADY CACHED: Scientific Name:Buteo lagopus',
#  'ALREADY CACHED: Scientific Name:Pluvialis squatarola',
#  'MESSAGE PROCESSED: Scientific Name:Urocitellus parryii',
#  'MESSAGE PROCESSED: Scientific Name:Regulus calendula grinnelli',
#  'ALREADY CACHED: Scientific Name:Lepus othus',
#  'ALREADY CACHED: Scientific Name:Lasionycteris noctivagans',
#  'MESSAGE PROCESSED: Scientific Name:Branta hutchinsii leucopareia',
#  'MESSAGE PROCESSED: Scientific Name:Junco hyemalis oreganus',
#  'ALREADY CACHED: Scientific Name:Hypomesus olidus',
#  'ALREADY CACHED: Scientific Name:Passerculus sandwichensis',
#  'MESSAGE PROCESSED: Scientific Name:Pusa hispida hispida',
#  'ALREADY CACHED: Scientific Name:Odobenus rosmarus',
#  'MESSAGE PROCESSED: Scientific Name:Amphipoda',
#  'MESSAGE PROCESSED: Scientific Name:Falco perigrinus',
#  'ALREADY CACHED: Scientific Name:Lota lota',
#  'ALREADY CACHED: Scientific Name:Rissa tridactyla',
#  'ALREADY CACHED: Scientific Name:Lepus americanus',
#  'ALREADY CACHED: Scientific Name:Contopus cooperi',
#  'ALREADY CACHED: Scientific Name:Cladocera',
#  'ALREADY CACHED: Scientific Name:Cygnus buccinator',
#  'ALREADY CACHED: Scientific Name:Larus hyperboreus',
#  'ALREADY CACHED: Scientific Name:Callorhinus ursinus',
#  'MESSAGE PROCESSED: Scientific Name:Limosa fedoa beringea',
#  'ALREADY CACHED: Scientific Name:Spinus pinus',
#  'ALREADY CACHED: Scientific Name:Prosopium cylindraceum',
#  'ALREADY CACHED: Scientific Name:Bubo scandiacus',
#  'ALREADY CACHED: Scientific Name:Calidris ptilocnemis tschuktschorum',
#  'MESSAGE PROCESSED: Scientific Name:Ptychoramphus aleuticus aleuticus',
#  'MESSAGE PROCESSED: Scientific Name:Numenius phaeopus hudsonicus',
#  'MESSAGE PROCESSED: Scientific Name:Oenathe oenanthe oenanthe',
#  'MESSAGE PROCESSED: Scientific Name:Pandalus hypsinotis',
#  'MESSAGE PROCESSED: Scientific Name:Troglodytes pacificus ochroleucus',
#  'ALREADY CACHED: Scientific Name:Limosa lapponica baueri',
#  'ALREADY CACHED: Scientific Name:Phalacrocorax urile',
#  'MESSAGE PROCESSED: Scientific Name:Oreothlypis celata',
#  'MESSAGE PROCESSED: Scientific Name:Clinocardium nuttallii',
#  'ALREADY CACHED: Scientific Name:Melospiza melodia',
#  'MESSAGE PROCESSED: Scientific Name:Stenodus leucichthys',
#  'ALREADY CACHED: Scientific Name:Tachycineta bicolor',
#  'MESSAGE PROCESSED: Scientific Name:Pandalus dispar',
#  'MESSAGE PROCESSED: Scientific Name:Fratercula corniculata',
#  'ALREADY CACHED: Scientific Name:Spizella arborea',
#  'MESSAGE PROCESSED: Scientific Name:Coregonus autumnalis autumnalis',
#  'ALREADY CACHED: Scientific Name:Geothlypis trichas',
#  'ALREADY CACHED: Scientific Name:Siliqua patula',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus clarki clarki',
#  'MESSAGE PROCESSED: Scientific Name:Troglodytes pacificus semediensis',
#  'ALREADY CACHED: Scientific Name:Buteo jamaicensis alascensis',
#  'ALREADY CACHED: Scientific Name:Empidonax difficilis',
#  'ALREADY CACHED: Scientific Name:Phoebastria albatrus',
#  'MESSAGE PROCESSED: Scientific Name:Salvelinus malma',
#  'ALREADY CACHED: Scientific Name:Riparia riparia',
#  'MESSAGE PROCESSED: Scientific Name:Geothlypis tolmiei',
#  'ALREADY CACHED: Scientific Name:Odonata',
#  'ALREADY CACHED: Scientific Name:Loxia leucoptera',
#  'MESSAGE PROCESSED: Scientific Name:Troglodytes pacificus helleri',
#  'ALREADY CACHED: Scientific Name:Asio flammeus flammeus',
#  'ALREADY CACHED: Scientific Name:Cryptochiton stelleri',
#  'ALREADY CACHED: Scientific Name:Microtus oeconomus',
#  'ALREADY CACHED: Scientific Name:Prosopium coulterii',
#  'MESSAGE PROCESSED: Scientific Name:Adonata adionata kennerlyi',
#  'MESSAGE PROCESSED: Scientific Name:Brachyramphus brevirostris',
#  'MESSAGE PROCESSED: Scientific Name:Poecile cinctus lathami',
#  'ALREADY CACHED: Scientific Name:Ursus maritimus',
#  'MESSAGE PROCESSED: Scientific Name:Lethenteron alaskense',
#  'MESSAGE PROCESSED: Scientific Name:Lethenteron camtschatica',
#  'MESSAGE PROCESSED: Scientific Name:Passerella iliaca insularis',
#  'MESSAGE PROCESSED: Scientific Name:Echinodermata',
#  'ALREADY CACHED: Scientific Name:Tamiasciurus hudsonicus kenaiensis',
#  'MESSAGE PROCESSED: Scientific Name:Perisoreus canadensis pacificus',
#  'ALREADY CACHED: Scientific Name:Bombycilla garrulus',
#  'ALREADY CACHED: Scientific Name:Phalaropus fulicarius',
#  'MESSAGE PROCESSED: Scientific Name:Sterocarius pomarinus',
#  'MESSAGE PROCESSED: Scientific Name:Acanthis flammea',
#  'ALREADY CACHED: Scientific Name:Lanius excubitor',
#  'ALREADY CACHED: Scientific Name:Numenius tahitiensis',
#  'ALREADY CACHED: Scientific Name:Glaucomys sabrinus griseifrons',
#  'MESSAGE PROCESSED: Scientific Name:Certhia americana alascensis',
#  'ALREADY CACHED: Scientific Name:Balaena mysticetus',
#  'MESSAGE PROCESSED: Scientific Name:Pinicola enucleator flammula',
#  'ALREADY CACHED: Scientific Name:Orcinus orca',
#  'ALREADY CACHED: Scientific Name:Ambystoma gracile',
#  'ALREADY CACHED: Scientific Name:Melospiza lincolnii',
#  'ALREADY CACHED: Scientific Name:Anser albifrons elgasi',
#  'MESSAGE PROCESSED: Scientific Name:Euphagus carolinus carolinus',
#  'MESSAGE PROCESSED: Scientific Name:Troglodytes pacificus meligerus',
#  'MESSAGE PROCESSED: Scientific Name:Passerella iliaca annectens',
#  'MESSAGE PROCESSED: Scientific Name:Hippolyte clarki',
#  'MESSAGE PROCESSED: Scientific Name:Strongylocentrotus franciscanus',
#  'ALREADY CACHED: Scientific Name:Tamiasciurus hudsonicus picatus',
#  'ALREADY CACHED: Scientific Name:Poecile rufescens',
#  'ALREADY CACHED: Scientific Name:Microtus pennsylvanicus',
#  'ALREADY CACHED: Scientific Name:Strongylocentrotus droebachiensis',
#  'MESSAGE PROCESSED: Scientific Name:Pandalus patyceros',
#  'MESSAGE PROCESSED: Scientific Name:Adonata beringiana',
#  'ALREADY CACHED: Scientific Name:Sebastes caurinus',
#  'MESSAGE PROCESSED: Scientific Name:Passerella iliaca chilkatensis',
#  'ALREADY CACHED: Scientific Name:Limosa haemastica',
#  'ALREADY CACHED: Scientific Name:Calidris melanotos',
#  'MESSAGE PROCESSED: Scientific Name:Protothaca stamineais',
#  'ALREADY CACHED: Scientific Name:Brachyramphus marmoratus',
#  'MESSAGE PROCESSED: Scientific Name:Sorex ugyunak',
#  'ALREADY CACHED: Scientific Name:Megaptera novaeangliae',
#  'MESSAGE PROCESSED: Scientific Name:Larus smithsonianus',
#  'ALREADY CACHED: Scientific Name:Lampetra ayresii',
#  'ALREADY CACHED: Scientific Name:Oceanodroma furcata furcata',
#  'ALREADY CACHED: Scientific Name:Myotis californicus',
#  'MESSAGE PROCESSED: Scientific Name:Chen canagica',
#  'MESSAGE PROCESSED: Scientific Name:Copepoda',
#  'MESSAGE PROCESSED: Scientific Name:Berryteuthis anonychus',
#  'MESSAGE PROCESSED: Scientific Name:Fulmarus glacialis',
#  'ALREADY CACHED: Scientific Name:Hirundo rustica',
#  'MESSAGE PROCESSED: Scientific Name:Urocitellus parryii osgoodi',
#  'ALREADY CACHED: Scientific Name:Aegolius funereus',
#  'MESSAGE PROCESSED: Scientific Name:Certhia americana occidentalis',
#  'ALREADY CACHED: Scientific Name:Taricha granulosa',
#  'ALREADY CACHED: Scientific Name:Catharus ustulatus',
#  'MESSAGE PROCESSED: Scientific Name:Urocitellus parryii nebulicola',
#  'ALREADY CACHED: Scientific Name:Sorex monticolus',
#  'MESSAGE PROCESSED: Scientific Name:Ophiodon elongates',
#  'ALREADY CACHED: Scientific Name:Haematopus bachmani',
#  'MESSAGE PROCESSED: Scientific Name:Urocitellus parryii kennicottii',
#  'MESSAGE PROCESSED: Scientific Name:Synthliboramphus antiquus antiquus',
#  'ALREADY CACHED: Scientific Name:Spirinchus thaleichthys',
#  'ALREADY CACHED: Scientific Name:Spizella passerina',
#  'ALREADY CACHED: Scientific Name:Sorex alaskanus',
#  'MESSAGE PROCESSED: Scientific Name:Sorex cinereus streatori',
#  'ALREADY CACHED: Scientific Name:Agelaius phoeniceus',
#  'ALREADY CACHED: Scientific Name:Selasphorus rufus',
#  'ALREADY CACHED: Scientific Name:Calcarius pictus',
#  'MESSAGE PROCESSED: Scientific Name:Saxidomus gigantean',
#  'MESSAGE PROCESSED: Scientific Name:Erignathus barbatus nauticus',
#  'MESSAGE PROCESSED: Scientific Name:Anser albifrons frontalis',
#  'ALREADY CACHED: Scientific Name:Tringa flavipes',
#  'ALREADY CACHED: Scientific Name:Lithobates sylvaticus',
#  'ALREADY CACHED: Scientific Name:Sterna paradisaea',
#  'ALREADY CACHED: Scientific Name:Aethia pygmaea',
#  'MESSAGE PROCESSED: Scientific Name:Aethia psittacula',
#  'MESSAGE PROCESSED: Scientific Name:Calidris alpina arcticola',
#  'ALREADY CACHED: Scientific Name:Myotis lucifugus',
#  'ALREADY CACHED: Scientific Name:Enteroctopus dofleini',
#  'ALREADY CACHED: Scientific Name:Picoides dorsalis',
#  'ALREADY CACHED: Scientific Name:Falco sparverius',
#  'MESSAGE PROCESSED: Scientific Name:Acanthis hornemanni',
#  'MESSAGE PROCESSED: Scientific Name:Cardellina pusilla pileolata',
#  'MESSAGE PROCESSED: Scientific Name:Urocitellus parryii albusus',
#  'ALREADY CACHED: Scientific Name:Ochotona collaris',
#  'ALREADY CACHED: Scientific Name:Calidris ptilocnemis ptilocnemis',
#  'MESSAGE PROCESSED: Scientific Name:Myodes rutilus',
#  'MESSAGE PROCESSED: Scientific Name:Plectrophenax nivalis nivalis',
#  'ALREADY CACHED: Scientific Name:Sphyrapicus ruber',
#  'MESSAGE PROCESSED: Scientific Name:Ixoreus naevius',
#  'ALREADY CACHED: Scientific Name:Esox lucius',
#  'ALREADY CACHED: Scientific Name:Megaceryle alcyon',
#  'ALREADY CACHED: Scientific Name:Sorex palustris',
#  'MESSAGE PROCESSED: Scientific Name:Paralithodes camtschaticus',
#  'MESSAGE PROCESSED: Scientific Name:Anoplopoma fimbria',
#  'ALREADY CACHED: Scientific Name:Pluvialis fulva',
#  'MESSAGE PROCESSED: Scientific Name:Melospiza melodia sanaka',
#  'ALREADY CACHED: Scientific Name:Pandalus borealis',
#  'ALREADY CACHED: Scientific Name:Myotis keenii',
#  'MESSAGE PROCESSED: Scientific Name:Branta hutchinsii minima',
#  'ALREADY CACHED: Scientific Name:Picoides arcticus',
#  'ALREADY CACHED: Scientific Name:Eschrichtius robustus',
#  'MESSAGE PROCESSED: Scientific Name:Larus canus brachyrhynchus',
#  'ALREADY CACHED: Scientific Name:Sebastes ruberrimus',
#  'ALREADY CACHED: Scientific Name:Arenaria melanocephala',
#  'ALREADY CACHED: Scientific Name:Tamiasciurus hudsonicus',
#  'MESSAGE PROCESSED: Scientific Name:Actitus macularius',
#  'MESSAGE PROCESSED: Scientific Name:Hippoglossus stenolepis',
#  'MESSAGE PROCESSED: Scientific Name:Entosphenus tridentate',
#  'MESSAGE PROCESSED: Scientific Name:Mysida',
#  'MESSAGE PROCESSED: Scientific Name:Branta hutchinsii taverneri',
#  'MESSAGE PROCESSED: Scientific Name:Erimacrus isenbeckii',
#  'ALREADY CACHED: Scientific Name:Pungitius pungitius',
#  'ALREADY CACHED: Scientific Name:Mallotus villosus',
#  'ALREADY CACHED: Scientific Name:Clangula hyemalis',
#  'MESSAGE PROCESSED: Scientific Name:Passerella iliaca unalaschcensis',
#  'MESSAGE PROCESSED: Scientific Name:Gadus microcephalus',
#  'MESSAGE PROCESSED: Scientific Name:Xema sabini',
#  'ALREADY CACHED: Scientific Name:Microtus longicaudus',
#  'ALREADY CACHED: Scientific Name:Passerella iliaca',
#  'ALREADY CACHED: Scientific Name:Canis lupus ligoni',
#  'MESSAGE PROCESSED: Scientific Name:Leucosticte tephrocotis griseonucha',
#  'MESSAGE PROCESSED: Scientific Name:Uria aalge inornata',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus keta',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus mykiss',
#  'ALREADY CACHED: Scientific Name:Anthus rubescens',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus nerka',
#  'ALREADY CACHED: Scientific Name:Setophaga striata',
#  'ALREADY CACHED: Scientific Name:Sebastes nebulosus',
#  'MESSAGE PROCESSED: Scientific Name:Spirinchus starksi',
#  'MESSAGE PROCESSED: Scientific Name:Mytilus trossulus',
#  'ALREADY CACHED: Scientific Name:Microtus miurus',
#  'MESSAGE PROCESSED: Scientific Name:Chionoecetes opilio',
#  'ALREADY CACHED: Scientific Name:Setophaga ruticilla',
#  'ALREADY CACHED: Scientific Name:Fratercula cirrhata',
#  'MESSAGE PROCESSED: Scientific Name:Aquila chrysaetos canadensis',
#  'MESSAGE PROCESSED: Scientific Name:Athya affinis',
#  'MESSAGE PROCESSED: Scientific Name:Urocitellus parryii lyratus',
#  'ALREADY CACHED: Scientific Name:Poecile hudsonicus',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus gorbuscha',
#  'MESSAGE PROCESSED: Scientific Name:Margaritifera falcate',
#  'MESSAGE PROCESSED: Scientific Name:Atheresthes stomias',
#  'MESSAGE PROCESSED: Scientific Name:Cancer magister',
#  'ALREADY CACHED: Scientific Name:Melospiza melodia maxima',
#  'MESSAGE PROCESSED: Scientific Name:Chionoecetes bairdi',
#  'MESSAGE PROCESSED: Scientific Name:Tringa solitaria cinnomomea',
#  'MESSAGE PROCESSED: Scientific Name:Parastichopus californicus',
#  'ALREADY CACHED: Scientific Name:Lepidoptera',
#  'MESSAGE PROCESSED: Scientific Name:Lithodes aequispinus',
#  'MESSAGE PROCESSED: Scientific Name:Coregonus sardinella',
#  'MESSAGE PROCESSED: Scientific Name:Catharus guttatus guttatus',
#  'ALREADY CACHED: Scientific Name:Osmerus mordax',
#  'MESSAGE PROCESSED: Scientific Name:Arachnida',
#  'ALREADY CACHED: Scientific Name:Dicrostonyx groenlandicus',
#  'MESSAGE PROCESSED: Scientific Name:Branta bernicula nigricans',
#  'ALREADY CACHED: Scientific Name:Plectrophenax hyperboreus',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus kisutch',
#  'ALREADY CACHED: Scientific Name:Grus canadensis canadensis',
#  'ALREADY CACHED: Scientific Name:Peromyscus keeni',
#  'ALREADY CACHED: Scientific Name:Calidris subruficollis',
#  'ALREADY CACHED: Scientific Name:Alle alle',
#  'MESSAGE PROCESSED: Scientific Name:Falco perigrinus pealei',
#  'MESSAGE PROCESSED: Scientific Name:Lemmus sibiricus',
#  'ALREADY CACHED: Scientific Name:Clupea pallasii',
#  'ALREADY CACHED: Scientific Name:Melanitta deglandi',
#  'MESSAGE PROCESSED: Scientific Name:Leucosticte tephrocotis umbrina',
#  'MESSAGE PROCESSED: Scientific Name:Chlamys rubida',
#  'MESSAGE PROCESSED: Scientific Name:Passerella iliaca townsendi',
#  'ALREADY CACHED: Scientific Name:Zapus hudsonius',
#  'ALREADY CACHED: Scientific Name:Tringa incana',
#  'MESSAGE PROCESSED: Scientific Name:Calidris alpina pacifica',
#  'ALREADY CACHED: Scientific Name:Ammodytes hexapterus',
#  'ALREADY CACHED: Scientific Name:Microtus xanthognathus',
#  'ALREADY CACHED: Scientific Name:Couesius plumbeus',
#  'ALREADY CACHED: Scientific Name:Circus cyaneus',
#  'MESSAGE PROCESSED: Scientific Name:Melospiza melodia insignis',
#  'ALREADY CACHED: Scientific Name:Sebastes alutus',
#  'ALREADY CACHED: Scientific Name:Sorex tundrensis',
#  'ALREADY CACHED: Scientific Name:Rissa brevirostris',
#  'MESSAGE PROCESSED: Scientific Name:Cepphus columba columba',
#  'ALREADY CACHED: Scientific Name:Coregonus laurettae',
#  'ALREADY CACHED: Scientific Name:Somateria fischeri',
#  'ALREADY CACHED: Scientific Name:Limnodromus scolopaceus',
#  'MESSAGE PROCESSED: Scientific Name:Dicrostonyx unalascensis',
#  'MESSAGE PROCESSED: Scientific Name:Catharus guttatus nanus',
#  'ALREADY CACHED: Scientific Name:Haliaeetus leucocephalus',
#  'ALREADY CACHED: Scientific Name:Sorex monticolus alascensis',
#  'ALREADY CACHED: Scientific Name:Diptera',
#  'MESSAGE PROCESSED: Scientific Name:Colaptes auratus luteus',
#  'MESSAGE PROCESSED: Scientific Name:Telmessus cheiragonus',
#  'ALREADY CACHED: Scientific Name:Lemmus trimucronatus',
#  'ALREADY CACHED: Scientific Name:Spizella breweri',
#  'ALREADY CACHED: Scientific Name:Thomomys idahoensis',
#  'MESSAGE PROCESSED: Scientific Name:Plestiodon skiltonianus utahensis',
#  'ALREADY CACHED: Scientific Name:Picoides dorsalis',
#  'ALREADY CACHED: Scientific Name:Oreoscoptes montanus',
#  'ALREADY CACHED: Scientific Name:Lasiurus borealis',
#  'ALREADY CACHED: Scientific Name:Apalone spinifera hartwegi',
#  'ALREADY CACHED: Scientific Name:Calamospiza melanocorys',
#  'ALREADY CACHED: Scientific Name:Aechmophorus clarkii',
#  'MESSAGE PROCESSED: Scientific Name:Eptisicus fuscus',
#  'ALREADY CACHED: Scientific Name:Corynorhinus townsendii',
#  'ALREADY CACHED: Scientific Name:Myotis evotis',
#  'ALREADY CACHED: Scientific Name:Euderma maculatum',
#  'ALREADY CACHED: Scientific Name:Crotalus oreganus concolor',
#  'MESSAGE PROCESSED: Scientific Name:Neotamias amoenus',
#  'ALREADY CACHED: Scientific Name:Lontra canadensis',
#  'ALREADY CACHED: Scientific Name:Thamnophis radix',
#  'ALREADY CACHED: Scientific Name:Opheodrys vernalis',
#  'ALREADY CACHED: Scientific Name:Campostoma anomalum',
#  'ALREADY CACHED: Scientific Name:Calcarius mccownii',
#  'ALREADY CACHED: Scientific Name:Nocomis biguttatus',
#  'ALREADY CACHED: Scientific Name:Mustela nivalis',
#  'MESSAGE PROCESSED: Scientific Name:Zapus hudsonius prebleii',
#  'ALREADY CACHED: Scientific Name:Heterodon nasicus',
#  'ALREADY CACHED: Scientific Name:Storeria occipitomaculata pahasapae',
#  'ALREADY CACHED: Scientific Name:Numenius americanus',
#  'ALREADY CACHED: Scientific Name:Aythya affinis',
#  'ALREADY CACHED: Scientific Name:Falco columbarius',
#  'ALREADY CACHED: Scientific Name:Antrozous pallidus',
#  'ALREADY CACHED: Scientific Name:Lasmigona complanata',
#  'ALREADY CACHED: Scientific Name:Spiza americana',
#  'ALREADY CACHED: Scientific Name:Picoides arcticus',
#  'ALREADY CACHED: Scientific Name:Larus pipixcan',
#  'ALREADY CACHED: Scientific Name:Lithobates pipiens',
#  'MESSAGE PROCESSED: Scientific Name:Combined account',
#  'ALREADY CACHED: Scientific Name:Buteo swainsoni',
#  'ALREADY CACHED: Scientific Name:Sorex preblei',
#  'ALREADY CACHED: Scientific Name:Histrionicus histrionicus',
#  'ALREADY CACHED: Scientific Name:Amphispiza belli',
#  'ALREADY CACHED: Scientific Name:Spea bombifrons',
#  'ALREADY CACHED: Scientific Name:Martes americana',
#  'ALREADY CACHED: Scientific Name:Phoxinus neogaeus',
#  'ALREADY CACHED: Scientific Name:Neotamias dorsalis',
#  'ALREADY CACHED: Scientific Name:Anaxyrus cognatus',
#  'ALREADY CACHED: Scientific Name:Charadrius montanus',
#  'ALREADY CACHED: Scientific Name:Rallus limicola',
#  'ALREADY CACHED: Scientific Name:Alces alces',
#  'ALREADY CACHED: Scientific Name:Geomys bursarius',
#  'ALREADY CACHED: Scientific Name:Catostomus latipinnis',
#  'ALREADY CACHED: Scientific Name:Macrhybopsis gelida',
#  'ALREADY CACHED: Scientific Name:Sorex vagrans',
#  'MESSAGE PROCESSED: Scientific Name:Thamnophis sirtalis parietalis',
#  'MESSAGE PROCESSED: Scientific Name:Aspidoscelis sexlineatus viridis',
#  'ALREADY CACHED: Scientific Name:Calcarius ornatus',
#  'ALREADY CACHED: Scientific Name:Chrysemys picta bellii',
#  'ALREADY CACHED: Scientific Name:Myotis ciliolabrum',
#  'ALREADY CACHED: Scientific Name:Athene cunicularia',
#  'ALREADY CACHED: Scientific Name:Gila robusta',
#  'ALREADY CACHED: Scientific Name:Grus canadensis tabida',
#  'ALREADY CACHED: Scientific Name:Bartramia longicauda',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus clarkii bouvieri',
#  'ALREADY CACHED: Scientific Name:Ovis canadensis',
#  'ALREADY CACHED: Scientific Name:Anodonta californiensis',
#  'ALREADY CACHED: Scientific Name:Buteo regalis',
#  'ALREADY CACHED: Scientific Name:Reithrodontomys montanus',
#  'ALREADY CACHED: Scientific Name:Perognathus flavescens',
#  'ALREADY CACHED: Scientific Name:Luxilus cornutus',
#  'ALREADY CACHED: Scientific Name:Physella spelunca',
#  'MESSAGE PROCESSED: Scientific Name:Plestiodon multivirgatus multivirgatus',
#  'ALREADY CACHED: Scientific Name:Glaucidium gnoma',
#  'ALREADY CACHED: Scientific Name:Sander canadensis',
#  'ALREADY CACHED: Scientific Name:Anaxyrus boreas boreas',
#  'ALREADY CACHED: Scientific Name:Baeolophus ridgwayi',
#  'ALREADY CACHED: Scientific Name:Perognathus flavus',
#  'ALREADY CACHED: Scientific Name:Pyrgulopsis robusta',
#  'ALREADY CACHED: Scientific Name:Peromyscus truei',
#  'ALREADY CACHED: Scientific Name:Lota lota',
#  'ALREADY CACHED: Scientific Name:Prosopium williamsoni',
#  'ALREADY CACHED: Scientific Name:Neotamias umbrinus',
#  'ALREADY CACHED: Scientific Name:Phrynosoma hernandesi',
#  'MESSAGE PROCESSED: Scientific Name:Leucosticte arata',
#  'ALREADY CACHED: Scientific Name:Cygnus buccinator',
#  'ALREADY CACHED: Scientific Name:Chaetodipus hispidus',
#  'MESSAGE PROCESSED: Scientific Name:Thamnophis sirtalis fitchi',
#  'ALREADY CACHED: Scientific Name:Cambarus diogenes',
#  'ALREADY CACHED: Scientific Name:Orconectes immunis',
#  'ALREADY CACHED: Scientific Name:Hiodon alosoides',
#  'MESSAGE PROCESSED: Scientific Name:Sorex hayden',
#  'ALREADY CACHED: Scientific Name:Brachylagus idahoensis',
#  'ALREADY CACHED: Scientific Name:Sorex hoyi',
#  'ALREADY CACHED: Scientific Name:Vulpes velox',
#  'ALREADY CACHED: Scientific Name:Rhinichthys osculus thermalis',
#  'ALREADY CACHED: Scientific Name:Orconectes neglectus',
#  'ALREADY CACHED: Scientific Name:Martes pennanti',
#  'ALREADY CACHED: Scientific Name:Charina bottae',
#  'ALREADY CACHED: Scientific Name:Leucosticte australis',
#  'MESSAGE PROCESSED: Scientific Name:Parognathus fasciatus',
#  'ALREADY CACHED: Scientific Name:Ammodramus savannarum',
#  'ALREADY CACHED: Scientific Name:Dolichonyx oryzivorus',
#  'MESSAGE PROCESSED: Scientific Name:Sceloporus consobrinus',
#  'ALREADY CACHED: Scientific Name:Phenacobius mirabilis',
#  'MESSAGE PROCESSED: Scientific Name:Anaxyrus baxteri',
#  'ALREADY CACHED: Scientific Name:Aythya americana',
#  'ALREADY CACHED: Scientific Name:Hybognathus placitus',
#  'ALREADY CACHED: Scientific Name:Urosaurus ornatus wrighti',
#  'ALREADY CACHED: Scientific Name:Terrapene ornata ornata',
#  'ALREADY CACHED: Scientific Name:Scaphirhynchus platorynchus',
#  'MESSAGE PROCESSED: Scientific Name:Oncorhynchus clarkii',
#  'ALREADY CACHED: Scientific Name:Empidonax traillii',
#  'ALREADY CACHED: Scientific Name:Etheostoma exile',
#  'ALREADY CACHED: Scientific Name:Hybognathus argyritis',
#  'ALREADY CACHED: Scientific Name:Pacifastacus gambelii',
#  'ALREADY CACHED: Scientific Name:Lampropeltis triangulum multistriata',
#  'ALREADY CACHED: Scientific Name:Aegolius funereus',
#  'ALREADY CACHED: Scientific Name:Etheostoma spectabile',
#  'ALREADY CACHED: Scientific Name:Aphelocoma californica',
#  'ALREADY CACHED: Scientific Name:Spea intermontana',
#  'ALREADY CACHED: Scientific Name:Anodontoides ferussacianus',
#  'ALREADY CACHED: Scientific Name:Pituophis catenifer deserticola',
#  'ALREADY CACHED: Scientific Name:Notropis dorsalis',
#  'ALREADY CACHED: Scientific Name:Fundulus kansae',
#  'ALREADY CACHED: Scientific Name:Rana luteiventris',
#  'ALREADY CACHED: Scientific Name:Chlidonias niger',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus clarkii utah',
#  'ALREADY CACHED: Scientific Name:Gavia immer',
#  'ALREADY CACHED: Scientific Name:Accipiter gentilis',
#  'ALREADY CACHED: Scientific Name:Margariscus margarita',
#  'ALREADY CACHED: Scientific Name:Bucephala islandica',
#  'ALREADY CACHED: Scientific Name:Fundulus sciadicus',
#  'ALREADY CACHED: Scientific Name:Ochotona princeps',
#  'ALREADY CACHED: Scientific Name:Egretta thula',
#  'ALREADY CACHED: Scientific Name:Mustela nigripes',
#  'ALREADY CACHED: Scientific Name:Myiarchus cinerascens',
#  'MESSAGE PROCESSED: Scientific Name:Holbrookia maculata maculata',
#  'ALREADY CACHED: Scientific Name:Peromyscus crinitus',
#  'ALREADY CACHED: Scientific Name:Psaltriparus minimus',
#  'ALREADY CACHED: Scientific Name:Hybognathus hankinsoni',
#  'ALREADY CACHED: Scientific Name:Gila copei',
#  'ALREADY CACHED: Scientific Name:Margaritifera falcata',
#  'ALREADY CACHED: Scientific Name:Lampsilis siliquoidea',
#  'ALREADY CACHED: Scientific Name:Anas acuta',
#  'ALREADY CACHED: Scientific Name:Coccyzus americanus',
#  'ALREADY CACHED: Scientific Name:Nycticorax nycticorax',
#  'ALREADY CACHED: Scientific Name:Glaucomys sabrinus',
#  'ALREADY CACHED: Scientific Name:Hydroprogne caspia',
#  'ALREADY CACHED: Scientific Name:Myotis volans',
#  'ALREADY CACHED: Scientific Name:Strix nebulosa',
#  'MESSAGE PROCESSED: Scientific Name:Spermopholis spilosoma',
#  'ALREADY CACHED: Scientific Name:Plegadis chihi',
#  'ALREADY CACHED: Scientific Name:Oncorhynchus clarkii pleuriticus',
#  'MESSAGE PROCESSED: Scientific Name:Myotis thysanode',
#  'ALREADY CACHED: Scientific Name:Asio flammeus',
#  'ALREADY CACHED: Scientific Name:Microtus richardsoni',
#  'ALREADY CACHED: Scientific Name:Catostomus discobolus',
#  'ALREADY CACHED: Scientific Name:Centrocercus urophasianus',
#  'ALREADY CACHED: Scientific Name:Melanerpes lewis',
#  'ALREADY CACHED: Scientific Name:Platygobio gracilis',
#  'ALREADY CACHED: Scientific Name:Botaurus lentiginosus',
#  'ALREADY CACHED: Scientific Name:Gulo gulo',
#  'ALREADY CACHED: Scientific Name:Lampsilis cardium',
#  'ALREADY CACHED: Scientific Name:Lithobates sylvaticus',
#  'ALREADY CACHED: Scientific Name:Tantilla nigriceps',
#  'ALREADY CACHED: Scientific Name:Sorex nanus',
#  'ALREADY CACHED: Scientific Name:Falco peregrinus',
#  'ALREADY CACHED: Scientific Name:Sitta pygmaea',
#  'ALREADY CACHED: Scientific Name:Lynx canadensis',
#  'ALREADY CACHED: Scientific Name:Tympanuchus phasianellus columbianus',
#  'ALREADY CACHED: Scientific Name:Perognathus parvus',
#  'ALREADY CACHED: Scientific Name:Aythya valisineria',
#  'ALREADY CACHED: Scientific Name:Myotis lucifugus',
#  'ALREADY CACHED: Scientific Name:Haliaeetus leucocephalus',
#  'ALREADY CACHED: Scientific Name:Myotis septentrionalis',
#  'ALREADY CACHED: Scientific Name:Sterna forsteri',
#  'ALREADY CACHED: Scientific Name:Thomomys clusius',
#  'ALREADY CACHED: Scientific Name:Pyganodon grandis',
#  'ALREADY CACHED: Scientific Name:Sternula antillarum athalassos',
#  'MESSAGE PROCESSED: Scientific Name:Perlesta dakota',
#  'ALREADY CACHED: Scientific Name:Calamospiza melanocorys',
#  'ALREADY CACHED: Scientific Name:Cicindela lepida',
#  'ALREADY CACHED: Scientific Name:Corynorhinus townsendii',
#  'ALREADY CACHED: Scientific Name:Graptemys pseudogeographica',
#  'MESSAGE PROCESSED: Scientific Name:Cicindela nevadica makosika',
#  'ALREADY CACHED: Scientific Name:Stylurus notatus',
#  'ALREADY CACHED: Scientific Name:Lontra canadensis',
#  'ALREADY CACHED: Scientific Name:Pelecanus erythrorhynchos',
#  'ALREADY CACHED: Scientific Name:Vertigo arthuri',
#  'ALREADY CACHED: Scientific Name:Nocomis biguttatus',
#  'ALREADY CACHED: Scientific Name:Hyla chrysoscelis',
#  'ALREADY CACHED: Scientific Name:Storeria occipitomaculata pahasapae',
#  'ALREADY CACHED: Scientific Name:Numenius americanus',
#  'ALREADY CACHED: Scientific Name:Percina caprodes',
#  'ALREADY CACHED: Scientific Name:Ammodramus leconteii',
#  'ALREADY CACHED: Scientific Name:Charadrius melodus',
#  'ALREADY CACHED: Scientific Name:Picoides arcticus',
#  'ALREADY CACHED: Scientific Name:Leptodea leptodon',
#  'ALREADY CACHED: Scientific Name:Anthus spragueii',
#  'ALREADY CACHED: Scientific Name:Cicindela limbata nympha',
#  'ALREADY CACHED: Scientific Name:Eumeces multivirgatus',
#  'MESSAGE PROCESSED: Scientific Name:Tamiasciurus hudsonicus dakotensis',
#  'ALREADY CACHED: Scientific Name:Catinella gelida',
#  'ALREADY CACHED: Scientific Name:Cycleptus elongatus',
#  'ALREADY CACHED: Scientific Name:Chrosomus eos',
#  'ALREADY CACHED: Scientific Name:Macrhybopsis gelida',
#  'ALREADY CACHED: Scientific Name:Tympanuchus cupido',
#  'ALREADY CACHED: Scientific Name:Tropidoclonion lineatum',
#  'ALREADY CACHED: Scientific Name:Calcarius ornatus',
#  'MESSAGE PROCESSED: Scientific Name:Margariscus nachtriebi',
#  'ALREADY CACHED: Scientific Name:Notropis heterolepis',
#  'ALREADY CACHED: Scientific Name:Hesperia ottoe',
#  'ALREADY CACHED: Scientific Name:Athene cunicularia',
#  'ALREADY CACHED: Scientific Name:Lasionycteris noctivagans',
#  'ALREADY CACHED: Scientific Name:Oarisma poweshiek',
#  'ALREADY CACHED: Scientific Name:Lampsilis higginsii',
#  'ALREADY CACHED: Scientific Name:Buteo regalis',
#  'ALREADY CACHED: Scientific Name:Heterodon platirhinos',
#  'ALREADY CACHED: Scientific Name:Spermophilus richardsonii',
#  'ALREADY CACHED: Scientific Name:Myotis thysanodes pahasapensis',
#  'ALREADY CACHED: Scientific Name:Chrosomus erythrogaster',
#  'ALREADY CACHED: Scientific Name:Apalone mutica',
#  'ALREADY CACHED: Scientific Name:Phrynosoma hernandesi',
#  'ALREADY CACHED: Scientific Name:Cygnus buccinator',
#  'ALREADY CACHED: Scientific Name:Vulpes velox',
#  'ALREADY CACHED: Scientific Name:Pandion haliaetus',
#  'ALREADY CACHED: Scientific Name:Spermophilus franklinii',
#  'ALREADY CACHED: Scientific Name:Alasmidonta marginata',
#  'ALREADY CACHED: Scientific Name:Speyeria idalia',
#  'ALREADY CACHED: Scientific Name:Fundulus diaphanus',
#  'ALREADY CACHED: Scientific Name:Scaphirhynchus platorynchus',
#  'ALREADY CACHED: Scientific Name:Notropis topeka',
#  'ALREADY CACHED: Scientific Name:Catostomus catostomus',
#  'ALREADY CACHED: Scientific Name:Chrosomus neogaeus',
#  'ALREADY CACHED: Scientific Name:Scaphirhynchus albus',
#  'ALREADY CACHED: Scientific Name:Obovaria olivaria',
#  'ALREADY CACHED: Scientific Name:Epitheca petechialis',
#  'ALREADY CACHED: Scientific Name:Phalaropus tricolor',
#  'ALREADY CACHED: Scientific Name:Holbrookia maculata',
#  'ALREADY CACHED: Scientific Name:Acris blanchardi',
#  'ALREADY CACHED: Scientific Name:Nicrophorus americanus',
#  'ALREADY CACHED: Scientific Name:Speyeria atlantis pahasapa',
#  'ALREADY CACHED: Scientific Name:Catoptrophorus semipalmatus',
#  'ALREADY CACHED: Scientific Name:Chlidonias niger',
#  'ALREADY CACHED: Scientific Name:Bonasa umbellus',
#  'ALREADY CACHED: Scientific Name:Catostomus platyrhynchus',
#  'ALREADY CACHED: Scientific Name:Cinclus mexicanus',
#  'ALREADY CACHED: Scientific Name:Accipiter gentilis',
#  'ALREADY CACHED: Scientific Name:Atrytone arogos iowa',
#  'ALREADY CACHED: Scientific Name:Hesperia dacotae',
#  'ALREADY CACHED: Scientific Name:Grus americana',
#  'ALREADY CACHED: Scientific Name:Mustela nigripes',
#  'ALREADY CACHED: Scientific Name:Amblycheila cylindriformis',
#  'ALREADY CACHED: Scientific Name:Terrapene ornata',
#  'ALREADY CACHED: Scientific Name:Lampsilis teres',
#  'ALREADY CACHED: Scientific Name:Ammodramus bairdii',
#  'ALREADY CACHED: Scientific Name:Junco hyemalis aikeni',
#  'ALREADY CACHED: Scientific Name:Vertigo paradoxa',
#  'ALREADY CACHED: Scientific Name:Quadrula quadrula',
#  'ALREADY CACHED: Scientific Name:Couesius plumbeus',
#  'ALREADY CACHED: Scientific Name:Glaucomys sabrinus',
#  'ALREADY CACHED: Scientific Name:Umbra limi',
#  'ALREADY CACHED: Scientific Name:Picoides tridactylus',
#  'ALREADY CACHED: Scientific Name:Sceloporus graciosus',
#  'ALREADY CACHED: Scientific Name:Percopsis omiscomaycus',
#  'ALREADY CACHED: Scientific Name:Centrocercus urophasianus',
#  'ALREADY CACHED: Scientific Name:Arcidens confragosus',
#  'ALREADY CACHED: Scientific Name:Melanerpes lewis',
#  'MESSAGE PROCESSED: Scientific Name:Analetris eximia',
#  'ALREADY CACHED: Scientific Name:Oreohelix strigosa cooperi',
#  'ALREADY CACHED: Scientific Name:Percina maculata',
#  'ALREADY CACHED: Scientific Name:Lasmigona compressa',
#  'ALREADY CACHED: Scientific Name:Falco peregrinus',
#  'ALREADY CACHED: Scientific Name:Notropis percobromus',
#  ...]

# %% [markdown]
# In assembling this workflow and thinking about it from the standpoint of asynchronous, message-based processing, I ran into a number of interesting dynamics. We end up pushing out a lot of essentially duplicate messages that have to be dealt with in the processors by checking some API to determine whether or not a given check needs to run. For instance, in processing through something like the SGCN lists or any list of species for any purpose, we're going to end up with the same species name from many different sources on one or more logical message queues triggering taxonomic lookups to ITIS or any of our other sources. We don't need to run lookup processes every single time, but our information gathering algorithms need to be "smart" enough to know when they should run something again to refresh data, and our receiving information systems need to have business rules established that understand how to absorb changed values from third party sources.
#
# ITIS lookups for SGCN present a number of different dynamics that deserve further scrutiny. The refresh cycle for ITIS itself is nominally monthly based on how the group operates that system. A monthly data update for ITIS generally includes taxonomic treatments for one or more entire taxonomic groups along with other incidental corrections and changes in the data discovered by the maintainers over time. That establishes one constraining end member. We may set up a central cyberinfrastructure that receives messages for looking up ITIS taxonomy from many different inbound vectors, processes those messages in a standardized way, and stores information in a dynamic cache. (In this local processing scheme, I've essentially set this up as the "sppin" database, containing cached data structures for each species information source I'm using here.) Every time a new message shows up, we check the cache first, look at dates for existing records, and re-run an ITIS lookup from source any time a 30 day threshold is exceeded. At any point, most records will probably not have changed, but those that have changed will probably need trigger an "itis_changed_record" message somewhere that signals that something needs to be evaluated for one or more dependent information systems. What exactly that change means is going to vary for those dependent systems, and that needs to be thought through as part of data management planning. In the case of SGCN, this could trigger a number of different things:
#
# * The total number of "National List" species could go up or down with changes in taxonomic understanding as species names are combined or split.
# * New names could need to be checked against other systems where additional information can be returned or new values derived.
# * Additional states could be shown to be listing the same species as synonyms are identified and established.
#
# All of these dynamics will impact applications using the data and reports being generated from the API, and keeping track of when specific records change in some way will likely be important. It is easy enough to use a device like I've used with this local system that uses a hash of a given record content to generate its primary key. This lets us use lazy processes to throw only unique records into a ledger, but we do have to determine what to do when multiple records respond to the same logical query, how to best report what changed between those records in our APIs, and how different systems should determine whether or not the change was significant to their particular business rules.
