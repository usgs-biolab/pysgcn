# %% [markdown]
# One of the main functions of the SGCN synthesis process is to conduct taxonomic matching on submitted names to determine when states are listing the same species even when they may refer to a different name. This process creates what we have referred to as the "SGCN National List," essentially any species that has been successfully matched to either ITIS or WoRMS as taxonomic authorities.
#
# The processors for ITIS and WoRMS take any valid record from the matching process, summarize a few specific properties, and send those to a message queue for processing here.

# %%
import pysgcn
sgcn = pysgcn.sgcn.Sgcn()

# %%
processable_item = sgcn.get_message("mq_taxa_summary")
processable_item
# Out:
# {'id': 'ebf888bb4ed9c110114d86f16ad9df07be0cf69f',
#  'date_inserted': '2019-12-19T13:14:07.380353',
#  'body': {'scientificname': 'Anodontoides radiatus',
#   'taxonomicrank': 'Species',
#   'taxonomic_authority_url': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=80149',
#   'match_method': 'Exact Match',
#   'commonname': 'rayed creekshell',
#   'sppin_key': 'Scientific Name:Anodontoides radiatus'}}

# %%
# %%time
while processable_item is not None:
    sgcn.update_taxa_summary_data(
        processable_item["body"]["sppin_key"],
        processable_item["body"]
    )
    sgcn.delete_message("mq_taxa_summary", processable_item["id"])
    processable_item = sgcn.get_message("mq_taxa_summary")
# Out:
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>, <Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# ...
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# None
# [<Table sgcn (id, scientific name, common name, taxonomic category, state, sciencebase_item_id, record_processed, source_file_date, source_file_url, year, clean_scientific_name, historic_list, itis_override_id, sppin_key, scientificname, taxonomicrank, taxonomic_authority_url, match_method, commonname)>]
# CPU times: user 5.24 s, sys: 5.26 s, total: 10.5 s
# Wall time: 11.5 s
