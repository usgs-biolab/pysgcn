# %% [markdown]
# # Pipeline Stage 4
# Two things happen on processing source files from ScienceBase:
#
# 1. Individual source records go into a message queue for validation and processing
# 2. Scientific names are extracted and placed onto a message queue for processing initially against ITIS
#
# In the current model of this process, we are creating a single database table containing all of the summarized properties for each name submitted by a State/Territory. That gives us the necessary data to respond to queries for each State/Territory but also to pull out the National List names.
#
# The body of the messages in the mq_source_records queue processed here contains the properties from source files with a little bit of processing metadata indicating exactly where the records came from (sciencebase_item_id, source_file_url, source_file_date) along with metadata infused from collection records (historic_list, itis_identifier). A byproduct of running this through the Sqlite process that I used for the local processing mode, using the feature from the sqlite_utils package to generate a hash_id from the record contents, is that we detect and reject duplicate records at this stage. There are a number of cases where the original source files from the states included duplicates of the same name record.

# %%
import pysgcn
sgcn = pysgcn.sgcn.Sgcn()

# %%
processable_item = sgcn.get_message("mq_source_records")
processable_item
# Out:
# {'id': 'e18630d5fe5fbf14e6be7ca55355bc9100ada7a2',
#  'date_inserted': '2019-12-20T20:28:09.247288',
#  'body': {'scientific name': 'Acipenser oxyrhinchus desotoi',
#   'common name': 'Gulf Sturgeon',
#   'taxonomic category': 'Fish',
#   'state': 'Louisiana',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cd0ae4b0d27deb3754f2',
#   'record_processed': '2019-12-20T20:28:08.826103',
#   'source_file_date': '2016-07-14T17:33:42.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cd0ae4b0d27deb3754f2?f=__disk__b4%2Fae%2Fbf%2Fb4aebf82009a2aaadaa4d7b84fdcade7589c722b',
#   'year': '2005',
#   'clean_scientific_name': 'Acipenser oxyrhinchus desotoi',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Acipenser oxyrhinchus desotoi'}}

# %%
# %%time
nonunique_records = list()
while processable_item is not None:
    try:
        sgcn.process_sgcn_source_record(processable_item["body"])
    except Exception as e:
        nonunique_records.append(processable_item["body"])
        print(e)
    sgcn.delete_message("mq_source_records", processable_item["id"])
    processable_item = sgcn.get_message("mq_source_records")
# Out:
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# UNIQUE constraint failed: sgcn.id
# CPU times: user 2min 21s, sys: 1min 45s, total: 4min 7s
# Wall time: 6min 33s

# %% [markdown]
# In the process of inserting the records into a database with a unique constraint built by generating an identifier as the MD5 hash of the record contents, we discover some duplicates. These seem to track back to actual duplicate entries in the original submissions which could have come about for a variery of reasons. The important part is that we do not lose any species/state/year combinations in the submitted data. The following codeblocks show the duplicate values we turned up and then check to make sure that we ended up with a species/state/year combination in the final data pushed to our table.

# %%
nonunique_records
# Out:
# [{'scientific name': 'Glyphyalinia sp.',
#   'common name': 'terrestrial snails',
#   'taxonomic category': 'Gastropod',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/595a9a13e4b0d1f9f0528537',
#   'record_processed': '2019-12-20T20:28:22.630481',
#   'source_file_date': '2017-07-03T19:24:06.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/595a9a13e4b0d1f9f0528537?f=__disk__e5%2F8b%2F61%2Fe58b61cae166b1965b572e8748189199ad848491',
#   'state': 'Tennessee',
#   'year': '2015',
#   'clean_scientific_name': 'Glyphyalinia',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Glyphyalinia'},
#  {'scientific name': 'Glyphyalinia sp.',
#   'common name': 'terrestrial snails',
#   'taxonomic category': 'Gastropod',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/595a9a13e4b0d1f9f0528537',
#   'record_processed': '2019-12-20T20:28:22.630481',
#   'source_file_date': '2017-07-03T19:24:06.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/595a9a13e4b0d1f9f0528537?f=__disk__e5%2F8b%2F61%2Fe58b61cae166b1965b572e8748189199ad848491',
#   'state': 'Tennessee',
#   'year': '2015',
#   'clean_scientific_name': 'Glyphyalinia',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Glyphyalinia'},
#  {'scientific name': 'Batrisodes sp.',
#   'common name': 'ant beetles',
#   'taxonomic category': 'Insect',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/595a9a13e4b0d1f9f0528537',
#   'record_processed': '2019-12-20T20:28:22.630481',
#   'source_file_date': '2017-07-03T19:24:06.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/595a9a13e4b0d1f9f0528537?f=__disk__e5%2F8b%2F61%2Fe58b61cae166b1965b572e8748189199ad848491',
#   'state': 'Tennessee',
#   'year': '2015',
#   'clean_scientific_name': 'Batrisodes',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Batrisodes'},
#  {'scientific name': 'Scoterpes sp.',
#   'common name': 'cave millipeds',
#   'taxonomic category': 'Millipede',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/595a9a13e4b0d1f9f0528537',
#   'record_processed': '2019-12-20T20:28:22.630481',
#   'source_file_date': '2017-07-03T19:24:06.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/595a9a13e4b0d1f9f0528537?f=__disk__e5%2F8b%2F61%2Fe58b61cae166b1965b572e8748189199ad848491',
#   'state': 'Tennessee',
#   'year': '2015',
#   'clean_scientific_name': 'Scoterpes',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Scoterpes'},
#  {'scientific name': 'Scoterpes sp.',
#   'common name': 'cave millipeds',
#   'taxonomic category': 'Millipede',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/595a9a13e4b0d1f9f0528537',
#   'record_processed': '2019-12-20T20:28:22.630481',
#   'source_file_date': '2017-07-03T19:24:06.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/595a9a13e4b0d1f9f0528537?f=__disk__e5%2F8b%2F61%2Fe58b61cae166b1965b572e8748189199ad848491',
#   'state': 'Tennessee',
#   'year': '2015',
#   'clean_scientific_name': 'Scoterpes',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Scoterpes'},
#  {'scientific name': 'Anas strepera',
#   'common name': 'Gadwall',
#   'taxonomic category': 'Birds',
#   'state': 'Ohio',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787d03ce4b0d27deb37553e',
#   'record_processed': '2019-12-20T20:29:02.506134',
#   'source_file_date': '2016-07-14T17:47:35.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787d03ce4b0d27deb37553e?f=__disk__e1%2F63%2F23%2Fe16323eccceba129076888fcde3e76304f04fd8d',
#   'year': '2005',
#   'clean_scientific_name': 'Anas strepera',
#   'historic_list': True,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Anas strepera'},
#  {'scientific name': 'Dendroica petechia',
#   'common name': 'Yellow Warbler',
#   'taxonomic category': 'Birds',
#   'state': 'Ohio',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787d03ce4b0d27deb37553e',
#   'record_processed': '2019-12-20T20:29:02.506134',
#   'source_file_date': '2016-07-14T17:47:35.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787d03ce4b0d27deb37553e?f=__disk__e1%2F63%2F23%2Fe16323eccceba129076888fcde3e76304f04fd8d',
#   'year': '2005',
#   'clean_scientific_name': 'Dendroica petechia',
#   'historic_list': True,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Dendroica petechia'},
#  {'scientific name': 'Phalaropus tricolor',
#   'common name': "Wilson's Phalarope",
#   'taxonomic category': 'Birds',
#   'state': 'Ohio',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787d03ce4b0d27deb37553e',
#   'record_processed': '2019-12-20T20:29:02.506134',
#   'source_file_date': '2016-07-14T17:47:35.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787d03ce4b0d27deb37553e?f=__disk__e1%2F63%2F23%2Fe16323eccceba129076888fcde3e76304f04fd8d',
#   'year': '2005',
#   'clean_scientific_name': 'Phalaropus tricolor',
#   'historic_list': True,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Phalaropus tricolor'},
#  {'scientific name': '[no scientific name]',
#   'common name': 'Neoleptoneta new species',
#   'taxonomic category': 'Cnidarians',
#   'state': 'Texas',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787d176e4b0d27deb375792',
#   'record_processed': '2019-12-20T20:29:58.148357',
#   'source_file_date': '2016-07-14T17:52:39.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787d176e4b0d27deb375792?f=__disk__2c%2Fcf%2F77%2F2ccf7762967ab583506b8ba3f5820bb1d5bef56e',
#   'year': '2005',
#   'clean_scientific_name': '',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:'},
#  {'scientific name': 'Astragalus shortianus',
#   'common name': "Short's Milkvetch",
#   'taxonomic category': 'Vascular Plants',
#   'state': 'Nebraska',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cf65e4b0d27deb375525',
#   'record_processed': '2019-12-20T20:30:56.753075',
#   'source_file_date': '2016-07-14T17:43:58.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cf65e4b0d27deb375525?f=__disk__d2%2F5a%2F05%2Fd25a051e0e436ce9c991dc8e8daecd06b04265f4',
#   'year': '2005',
#   'clean_scientific_name': 'Astragalus shortianus',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Astragalus shortianus'},
#  {'scientific name': 'Carex missouriensis',
#   'common name': 'Missouri Sedge',
#   'taxonomic category': 'Vascular Plants',
#   'state': 'Nebraska',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cf65e4b0d27deb375525',
#   'record_processed': '2019-12-20T20:30:56.753075',
#   'source_file_date': '2016-07-14T17:43:58.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cf65e4b0d27deb375525?f=__disk__d2%2F5a%2F05%2Fd25a051e0e436ce9c991dc8e8daecd06b04265f4',
#   'year': '2005',
#   'clean_scientific_name': 'Carex missouriensis',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Carex missouriensis'},
#  {'scientific name': 'Cypripedium candidum',
#   'common name': "Small White Lady's-Slipper",
#   'taxonomic category': 'Vascular Plants',
#   'state': 'Nebraska',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cf65e4b0d27deb375525',
#   'record_processed': '2019-12-20T20:30:56.753075',
#   'source_file_date': '2016-07-14T17:43:58.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cf65e4b0d27deb375525?f=__disk__d2%2F5a%2F05%2Fd25a051e0e436ce9c991dc8e8daecd06b04265f4',
#   'year': '2005',
#   'clean_scientific_name': 'Cypripedium candidum',
#   'historic_list': True,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Cypripedium candidum'},
#  {'scientific name': 'Eriogonum gordonii',
#   'common name': "Gordon's Wild Buckwheat",
#   'taxonomic category': 'Vascular Plants',
#   'state': 'Nebraska',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cf65e4b0d27deb375525',
#   'record_processed': '2019-12-20T20:30:56.753075',
#   'source_file_date': '2016-07-14T17:43:58.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cf65e4b0d27deb375525?f=__disk__d2%2F5a%2F05%2Fd25a051e0e436ce9c991dc8e8daecd06b04265f4',
#   'year': '2005',
#   'clean_scientific_name': 'Eriogonum gordonii',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Eriogonum gordonii'},
#  {'scientific name': 'Pedicularis crenulata',
#   'common name': 'Meadow Lousewort',
#   'taxonomic category': 'Vascular Plants',
#   'state': 'Nebraska',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cf65e4b0d27deb375525',
#   'record_processed': '2019-12-20T20:30:56.753075',
#   'source_file_date': '2016-07-14T17:43:58.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cf65e4b0d27deb375525?f=__disk__d2%2F5a%2F05%2Fd25a051e0e436ce9c991dc8e8daecd06b04265f4',
#   'year': '2005',
#   'clean_scientific_name': 'Pedicularis crenulata',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Pedicularis crenulata'},
#  {'scientific name': 'Rallus elegans',
#   'common name': 'King Rail',
#   'taxonomic category': 'Birds',
#   'state': 'Nebraska',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cf65e4b0d27deb375525',
#   'record_processed': '2019-12-20T20:30:56.753075',
#   'source_file_date': '2016-07-14T17:43:58.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cf65e4b0d27deb375525?f=__disk__d2%2F5a%2F05%2Fd25a051e0e436ce9c991dc8e8daecd06b04265f4',
#   'year': '2005',
#   'clean_scientific_name': 'Rallus elegans',
#   'historic_list': True,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Rallus elegans'},
#  {'scientific name': 'Salicornia rubra',
#   'common name': 'Saltwort',
#   'taxonomic category': 'Vascular Plants',
#   'state': 'Nebraska',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cf65e4b0d27deb375525',
#   'record_processed': '2019-12-20T20:30:56.753075',
#   'source_file_date': '2016-07-14T17:43:58.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cf65e4b0d27deb375525?f=__disk__d2%2F5a%2F05%2Fd25a051e0e436ce9c991dc8e8daecd06b04265f4',
#   'year': '2005',
#   'clean_scientific_name': 'Salicornia rubra',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Salicornia rubra'},
#  {'scientific name': 'Megascops kennicottii',
#   'common name': 'Western Screech-Owl',
#   'taxonomic category': 'Birds',
#   'state': 'Alaska',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787c926e4b0d27deb37549e',
#   'record_processed': '2019-12-20T20:31:41.145729',
#   'source_file_date': '2016-07-14T17:17:16.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787c926e4b0d27deb37549e?f=__disk__59%2Fac%2F3f%2F59ac3f2e992076c5eb6b9d9bf28e10768d81b327',
#   'year': '2005',
#   'clean_scientific_name': 'Megascops kennicottii',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Megascops kennicottii'},
#  {'scientific name': 'Campeloma decisum',
#   'common name': 'Pointed Campeloma',
#   'taxonomic category': 'Gastropods',
#   'state': 'Indiana',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cc9ce4b0d27deb3754e6',
#   'record_processed': '2019-12-20T20:32:09.461268',
#   'source_file_date': '2016-07-14T17:31:54.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cc9ce4b0d27deb3754e6?f=__disk__b2%2F1f%2Fd7%2Fb21fd7323fa0cacc2b9bbdaf075185a98cdd7b23',
#   'year': '2005',
#   'clean_scientific_name': 'Campeloma decisum',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Campeloma decisum'},
#  {'scientific name': 'Lymnaea stagnalis',
#   'common name': 'Swamp Lymnaea',
#   'taxonomic category': 'Gastropods',
#   'state': 'Indiana',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cc9ce4b0d27deb3754e6',
#   'record_processed': '2019-12-20T20:32:09.461268',
#   'source_file_date': '2016-07-14T17:31:54.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cc9ce4b0d27deb3754e6?f=__disk__b2%2F1f%2Fd7%2Fb21fd7323fa0cacc2b9bbdaf075185a98cdd7b23',
#   'year': '2005',
#   'clean_scientific_name': 'Lymnaea stagnalis',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Lymnaea stagnalis'},
#  {'scientific name': 'Fallicambarus houstonensis ',
#   'common name': 'Houston burrowing crayfish ',
#   'taxonomic category': 'Crustaceans',
#   'state': 'Texas',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/57853325e4b0e02680bf1f87',
#   'record_processed': '2019-12-20T20:32:15.554781',
#   'source_file_date': '2017-06-23T13:30:51.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/57853325e4b0e02680bf1f87?f=__disk__dc%2Feb%2Fbb%2Fdcebbbaa32a512988269663509df8d5c221cb7a0',
#   'year': '2015',
#   'clean_scientific_name': 'Fallicambarus houstonensis',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Fallicambarus houstonensis'},
#  {'scientific name': 'Plauditus texanus ',
#   'common name': 'A mayfly',
#   'taxonomic category': 'Insects',
#   'state': 'Texas',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/57853325e4b0e02680bf1f87',
#   'record_processed': '2019-12-20T20:32:15.554781',
#   'source_file_date': '2017-06-23T13:30:51.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/57853325e4b0e02680bf1f87?f=__disk__dc%2Feb%2Fbb%2Fdcebbbaa32a512988269663509df8d5c221cb7a0',
#   'year': '2015',
#   'clean_scientific_name': 'Plauditus texanus',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Plauditus texanus'},
#  {'scientific name': 'Procloeon vicinum',
#   'common name': 'A mayfly',
#   'taxonomic category': 'Insects',
#   'state': 'New York',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787d01de4b0d27deb37553a',
#   'record_processed': '2019-12-20T20:32:40.509277',
#   'source_file_date': '2016-07-14T17:46:50.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787d01de4b0d27deb37553a?f=__disk__db%2F9a%2F73%2Fdb9a7396779821cbad0b0fde45279e5ce35618e5',
#   'year': '2005',
#   'clean_scientific_name': 'Procloeon vicinum',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Procloeon vicinum'},
#  {'scientific name': 'Pungitius pungitius occidentalis',
#   'common name': 'N. American ninespine stickleback',
#   'taxonomic category': 'Fish',
#   'state': 'New York',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787d01de4b0d27deb37553a',
#   'record_processed': '2019-12-20T20:32:40.509277',
#   'source_file_date': '2016-07-14T17:46:50.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787d01de4b0d27deb37553a?f=__disk__db%2F9a%2F73%2Fdb9a7396779821cbad0b0fde45279e5ce35618e5',
#   'year': '2005',
#   'clean_scientific_name': 'Pungitius pungitius occidentalis',
#   'historic_list': False,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Pungitius pungitius occidentalis'},
#  {'scientific name': 'Lepidochelys kempii',
#   'common name': "Kemp's Ridley Sea Turtle",
#   'taxonomic category': 'Reptile',
#   'state': 'South Carolina',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/56d72436e4b015c306f457eb',
#   'record_processed': '2019-12-20T20:34:25.080690',
#   'source_file_date': '2017-06-23T00:00:12.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/56d72436e4b015c306f457eb?f=__disk__79%2F47%2Ff5%2F7947f536a21bf6c2045e93bca54bf2dba95da896',
#   'year': '2015',
#   'clean_scientific_name': 'Lepidochelys kempii',
#   'historic_list': True,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Lepidochelys kempii'},
#  {'scientific name': 'Ambystoma laterale',
#   'common name': 'Blue-spotted Salamander',
#   'taxonomic category': 'Amphibians',
#   'state': 'Connecticut',
#   'sciencebase_item_id': 'https://www.sciencebase.gov/catalog/item/5787cafde4b0d27deb3754be',
#   'record_processed': '2019-12-20T20:34:31.325695',
#   'source_file_date': '2016-07-14T17:25:02.000Z',
#   'source_file_url': 'https://www.sciencebase.gov/catalog/file/get/5787cafde4b0d27deb3754be?f=__disk__52%2F54%2F70%2F5254704de4798497eca2f42f42ecce9d224a9a98',
#   'year': '2005',
#   'clean_scientific_name': 'Ambystoma laterale',
#   'historic_list': True,
#   'itis_override_id': None,
#   'sppin_key': 'Scientific Name:Ambystoma laterale'}]

# %%
for record in nonunique_records:
    if f'{record["state"]}_{record["year"]}' not in [f'{r["state"]}_{r["year"]}' for r in sgcn.sql_data.get_select_records(
        "sgcn",
        "sgcn",
        "clean_scientific_name = ?",
        record["clean_scientific_name"]
    )]:
        print(record)

# %% [markdown]
# At this point in the process we have the start to a final SGCN table containing all records for all states, years, and submitted names in a schema that contains source properties and infused metadata tracking the ScienceBase provenance for each record. We can now proceed to build out additional properties for our simple, synthesized data model to include summaries of valid taxon matches from ITIS or WoRMS as well as other useful details on Federal listing status, conservation status from recognized sources (IUCN, NatureServe), and other summary properties that may prove useful in examining the SGCN species list overall.
